# %%
import pandas as pd

# %%
df= pd.read_csv('C:/Users/DR/Desktop/moving computer/UCD CERT in DATA/economic_freedom_index2019_data.csv', index_col=0)

# %%
df.head()
# Out:
#           Country Name      WEBNAME                        Region  World Rank  \
# CountryID
# 1          Afghanistan  Afghanistan                  Asia-Pacific       152.0
# 2              Albania      Albania                        Europe        52.0
# 3              Algeria      Algeria  Middle East and North Africa       171.0
# 4               Angola       Angola            Sub-Saharan Africa       156.0
# 5            Argentina    Argentina                      Americas       148.0
#
#            Region Rank  2019 Score  Property Rights  Judical Effectiveness  \
# CountryID
# 1                 39.0        51.5             19.6                   29.6
# 2                 27.0        66.5             54.8                   30.6
# 3                 14.0        46.2             31.6                   36.2
# 4                 33.0        50.6             35.9                   26.6
# 5                 26.0        52.2             47.8                   44.5
#
# ...

# %%
df.tail()
# Out:
#           Country Name    WEBNAME                        Region  World Rank  \
# CountryID
# 179          Venezuela  Venezuela                      Americas       179.0
# 180            Vietnam    Vietnam                  Asia-Pacific       128.0
# 181              Yemen      Yemen  Middle East and North Africa         NaN
# 182             Zambia     Zambia            Sub-Saharan Africa       138.0
# 183           Zimbabwe   Zimbabwe            Sub-Saharan Africa       175.0
#
#            Region Rank  2019 Score  Property Rights  Judical Effectiveness  \
# CountryID
# 179               32.0        25.9              7.6                   13.1
# 180               30.0        55.3             49.8                   40.3
# 181                NaN         NaN             19.6                   22.2
# 182               27.0        53.6             45.0                   35.6
# 183               45.0        40.4             29.7                   24.8
#
# ...

# %%
df.describe()
# Out:
#        World Rank  Region Rank  2019 Score  Property Rights  \
# count  180.000000   180.000000  180.000000       185.000000
# mean    90.500000    20.538889   60.768333        52.327568
# std     52.105662    12.738611   11.255725        19.608526
# min      1.000000     1.000000    5.900000         7.600000
# 25%     45.750000     9.750000   53.950000        37.000000
# 50%     90.500000    19.500000   60.750000        50.100000
# 75%    135.250000    31.000000   67.800000        65.900000
# max    180.000000    47.000000   90.200000        97.400000
#
#        Judical Effectiveness  Government Integrity  Tax Burden  \
# count             185.000000            185.000000  180.000000
# mean               44.899459             41.470270   77.212778
# std                18.104745             19.793193   13.208314
# min                 5.000000              7.900000    0.000000
# 25%                31.000000             27.200000   70.975000
# ...

# %%
df["Tax Burden"]
# Out:
# CountryID
# 1      91.7
# 2      86.3
# 3      76.4
# 4      83.9
# 5      69.3
#        ...
# 179    74.7
# 180    79.7
# 181     NaN
# 182    72.3
# 183    62.3
# Name: Tax Burden, Length: 186, dtype: float64

# %%
list_of_columns = ["Property Rights", "Gov't Spending"]
df[list_of_columns]
# Out:
#            Property Rights  Gov't Spending
# CountryID
# 1                     19.6            80.3
# 2                     54.8            73.9
# 3                     31.6            48.7
# 4                     35.9            80.7
# 5                     47.8            49.5
# ...                    ...             ...
# 179                    7.6            58.1
# 180                   49.8            74.1
# 181                   19.6            83.7
# 182                   45.0            80.1
# 183                   29.7            74.5
#
# [186 rows x 2 columns]

# %%
df.loc[df["Country Name"]=="Australia"]
# Out:
#           Country Name    WEBNAME        Region  World Rank  Region Rank  \
# CountryID
# 7            Australia  Australia  Asia-Pacific         5.0          4.0
#
#            2019 Score  Property Rights  Judical Effectiveness  \
# CountryID
# 7                80.9             79.1                   86.5
#
#            Government Integrity  Tax Burden  ...    Country  \
# CountryID                                    ...
# 7                          79.9        62.8  ...  Australia
#
#            Population (Millions)  GDP (Billions, PPP)  GDP Growth Rate (%)  \
# CountryID
# 7                           24.8            $1,246.5                   2.3
#
#            5 Year GDP Growth Rate (%)  GDP per Capita (PPP)  Unemployment (%)  \
# CountryID
# 7                                 2.4               $50,334               5.6
#
#            Inflation (%)  FDI Inflow (Millions)  Public Debt (% of GDP)
# CountryID
# 7                    2.0              46,368.00                    41.6
# ...

# %%
df1=df[0:2]

# %%
df1
# Out:
#           Country Name      WEBNAME        Region  World Rank  Region Rank  \
# CountryID
# 1          Afghanistan  Afghanistan  Asia-Pacific       152.0         39.0
# 2              Albania      Albania        Europe        52.0         27.0
#
#            2019 Score  Property Rights  Judical Effectiveness  \
# CountryID
# 1                51.5             19.6                   29.6
# 2                66.5             54.8                   30.6
#
#            Government Integrity  Tax Burden  ...      Country  \
# CountryID                                    ...
# 1                          25.2        91.7  ...  Afghanistan
# 2                          40.4        86.3  ...      Albania
#
#            Population (Millions)  GDP (Billions, PPP)  GDP Growth Rate (%)  \
# CountryID
# 1                           35.5               $69.6                   2.5
# 2                            2.9               $36.0                   3.9
#
# ...

# %%
df1["World Rank"] == "Region Rank"
# Out:
# CountryID
# 1    False
# 2    False
# Name: World Rank, dtype: bool

# %%
df1["World Rank"] > 100
# Out:
# CountryID
# 1     True
# 2    False
# Name: World Rank, dtype: bool

# %%
df.isna().sum()
# Out:
# Country Name                   0
# WEBNAME                        0
# Region                         0
# World Rank                     6
# Region Rank                    6
# 2019 Score                     6
# Property Rights                1
# Judical Effectiveness          1
# Government Integrity           1
# Tax Burden                     6
# Gov't Spending                 3
# Fiscal Health                  3
# Business Freedom               1
# Labor Freedom                  2
# Monetary Freedom               2
# Trade Freedom                  4
# Investment Freedom             2
# Financial Freedom              5
# Tariff Rate (%)                4
# Income Tax Rate (%)            3
# Corporate Tax Rate (%)         3
# Tax Burden % of GDP            7
# Gov't Expenditure % of GDP     4
# Country                        0
# Population (Millions)          0
# GDP (Billions, PPP)            1
# GDP Growth Rate (%)            2
# 5 Year GDP Growth Rate (%)     3
# ...

# %%
df.shape
# Out:
# (186, 33)

# %%
# Import data from SQL

# %%
# This is importing data from SQL

# %%
pip install mysql-connector-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import mysql.connector

# %%
mydb = mysql.connector.connect(
    host="127.0.0.1",
    user="root",
    password="password1234!",
    database='vendas')

# %%
mycursor = mydb.cursor()
mycursor

# %%
mycursor.execute("Select * from vendas.covid")

# %%
myresults = mycursor.fetchall()
type(myresults)
# Out:
# list

# %%
myresults[0]
# Out:
# ('Afghanistan', 2201)

# %%
df_SQL = []   # Initialising empty list
for x in myresults:    # for loop to append each entry to a new list of lists
    df_SQL.append(list(x)) 
df_SQL = pd.DataFrame(df_SQL)  # Convert list of lists into a DataFrame
df_SQL.columns = mycursor.column_names # Add the columns names
df_SQL.head()
# Out:
#   Country Name  Covid-19 Deaths
# 0  Afghanistan             2201
# 1      Albania             1181
# 2      Algeria             2762
# 3      Andorra               84
# 4       Angola               33

# %%
improved_df_SQL=df_SQL.iloc[:,0:2]

# %%
improved_df_SQL
# Out:
#     Country Name  Covid-19 Deaths
# 0    Afghanistan             2201
# 1        Albania             1181
# 2        Algeria             2762
# 3        Andorra               84
# 4         Angola               33
# ..           ...              ...
# 186      Vietnam               35
# 187        Wales              512
# 188        Yemen              610
# 189       Zambia              390
# 190     Zimbabwe              369
#
# [191 rows x 2 columns]

# %%
df.groupby('Region').mean()
# Out:
#                               World Rank  Region Rank  2019 Score  \
# Region
# Americas                       90.156250         16.5   59.600000
# Asia-Pacific                   92.767442         22.0   60.634884
# Europe                         48.863636         22.5   68.627273
# Middle East and North Africa   90.285714          7.5   61.257143
# Sub-Saharan Africa            127.702128         24.0   54.182979
#
#                               Property Rights  Judical Effectiveness  \
# Region
# Americas                            48.265625              40.212500
# Asia-Pacific                        54.044186              46.116279
# Europe                              70.031818              56.590909
# Middle East and North Africa        47.966667              44.827778
# Sub-Saharan Africa                  38.904167              36.243750
#
#                               Government Integrity  Tax Burden  \
# Region
# ...

# %%
df.groupby('Region').median()
# Out:
#                               World Rank  Region Rank  2019 Score  \
# Region
# Americas                            80.5         16.5       62.20
# Asia-Pacific                       105.0         22.0       57.80
# Europe                              45.0         22.5       67.95
# Middle East and North Africa        89.0          7.5       60.90
# Sub-Saharan Africa                 134.0         24.0       54.00
#
#                               Property Rights  Judical Effectiveness  \
# Region
# Americas                                49.15                  37.75
# Asia-Pacific                            49.90                  42.50
# Europe                                  70.65                  51.75
# Middle East and North Africa            51.05                  45.20
# Sub-Saharan Africa                      35.85                  34.40
#
#                               Government Integrity  Tax Burden  \
# Region
# ...

# %%
df_group1=df.groupby(['Region', 'GDP per Capita (PPP)']).median()
df_group1
# Out:
#                                          World Rank  Region Rank  2019 Score  \
# Region             GDP per Capita (PPP)
# Americas           $1,815                     143.0         25.0        52.7
#                    $11,102                     72.0         14.0        63.6
#                    $11,482                    170.0         29.0        46.9
#                    $11,491                     55.0         10.0        65.8
#                    $12,114                    179.0         32.0        25.9
# ...                                             ...          ...         ...
# Sub-Saharan Africa $6,944                      73.0          4.0        63.1
#                    $677                       161.0         38.0        49.1
#                    $735                       162.0         39.0        48.9
#                    $790                       157.0         34.0        50.3
#                    $9,884                     132.0         23.0        54.7
#
# ...

# %%
df_group2=df.groupby(['Region'])['Inflation (%)'].agg(['mean','median'])
df_group2
# Out:
#                                    mean  median
# Region
# Americas                      38.368750    3.05
# Asia-Pacific                   3.595238    3.20
# Europe                         2.579545    1.85
# Middle East and North Africa   5.417647    2.00
# Sub-Saharan Africa             7.282979    5.30

# %%
df_no_dollar=df.replace('$','')

# %%
show=df['GDP per Capita (PPP)']

# %%
show
# Out:
# CountryID
# 1       $1,958
# 2      $12,507
# 3      $15,237
# 4       $6,753
# 5      $20,876
#         ...
# 179    $12,114
# 180     $6,913
# 181     $1,287
# 182     $3,996
# 183     $2,283
# Name: GDP per Capita (PPP), Length: 186, dtype: object

# %%
show2=df_no_dollar['GDP per Capita (PPP)']

# %%
show2
# Out:
# CountryID
# 1       $1,958
# 2      $12,507
# 3      $15,237
# 4       $6,753
# 5      $20,876
#         ...
# 179    $12,114
# 180     $6,913
# 181     $1,287
# 182     $3,996
# 183     $2,283
# Name: GDP per Capita (PPP), Length: 186, dtype: object

# %%
df['GDP per Capita no Dollar']=df['GDP per Capita (PPP)'].replace("[^0-9\.-]","", regex=True)

# %%
df['GDP per Capita no Dollar']
# Out:
# CountryID
# 1       1958
# 2      12507
# 3      15237
# 4       6753
# 5      20876
#        ...
# 179    12114
# 180     6913
# 181     1287
# 182     3996
# 183     2283
# Name: GDP per Capita no Dollar, Length: 186, dtype: object

# %%
df.head()
# Out:
#           Country Name      WEBNAME                        Region  World Rank  \
# CountryID
# 1          Afghanistan  Afghanistan                  Asia-Pacific       152.0
# 2              Albania      Albania                        Europe        52.0
# 3              Algeria      Algeria  Middle East and North Africa       171.0
# 4               Angola       Angola            Sub-Saharan Africa       156.0
# 5            Argentina    Argentina                      Americas       148.0
#
#            Region Rank  2019 Score  Property Rights  Judical Effectiveness  \
# CountryID
# 1                 39.0        51.5             19.6                   29.6
# 2                 27.0        66.5             54.8                   30.6
# 3                 14.0        46.2             31.6                   36.2
# 4                 33.0        50.6             35.9                   26.6
# 5                 26.0        52.2             47.8                   44.5
#
# ...

# %%
df.dtypes #Important
# Out:
# Country Name                    object
# WEBNAME                         object
# Region                          object
# World Rank                     float64
# Region Rank                    float64
# 2019 Score                     float64
# Property Rights                float64
# Judical Effectiveness          float64
# Government Integrity           float64
# Tax Burden                     float64
# Gov't Spending                 float64
# Fiscal Health                  float64
# Business Freedom               float64
# Labor Freedom                  float64
# Monetary Freedom               float64
# Trade Freedom                  float64
# Investment Freedom             float64
# Financial Freedom              float64
# Tariff Rate (%)                float64
# Income Tax Rate (%)            float64
# Corporate Tax Rate (%)         float64
# Tax Burden % of GDP            float64
# Gov't Expenditure % of GDP     float64
# Country                         object
# ...

# %%
df.astype({:float}).dtypes
# Out:
#   File "<ipython-input-74-6e9a4841cee0>", line 1
#     df.astype({:float}).dtypes
#                ^
# SyntaxError: invalid syntax

# %%
df_group3=df.groupby(['Region'])["GDP Growth Rate (%)"].agg(['mean','median'])
df_group3
# Out:
#                                   mean  median
# Region
# Americas                      1.587500    2.20
# Asia-Pacific                  4.332558    4.00
# Europe                        3.468182    3.25
# Middle East and North Africa  4.817647    2.00
# Sub-Saharan Africa            3.477083    3.75

# %%
df_group4=df.groupby(['Region'])["Business Freedom"].agg(['mean','median'])
df_group4
# Out:
#                                    mean  median
# Region
# Americas                      62.368750   64.50
# Asia-Pacific                  66.146512   67.30
# Europe                        74.797727   75.10
# Middle East and North Africa  63.027778   64.05
# Sub-Saharan Africa            51.758333   53.30

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
plt.scatter(df['Region'], df['Business Freedom'], s=2)
plt.show()

# %%
df_gdp= pd.read_csv('C:/Users/DR/Desktop/moving computer/UCD CERT in DATA/GDP.csv', index_col=0)

# %%
df_gdp.head()
# Out:
#             Country Code          1990          1991          1992  \
# Country
# Aruba                ABW  24101.109430  25870.755940  26533.343900
# Afghanistan          AFG           NaN           NaN           NaN
# Angola               AGO   3089.683369   3120.356148   2908.160798
# Albania              ALB   2549.473022   1909.114038   1823.307673
# Arab World           ARB   6808.206995   6872.273195   7255.328362
#
#                      1993          1994          1995          1996  \
# Country
# Aruba        27430.752400  28656.520210  28648.990020  28499.089430
# Afghanistan           NaN           NaN           NaN           NaN
# Angola        2190.768160   2195.532289   2496.199493   2794.896906
# Albania       2057.449657   2289.873135   2665.764906   2980.066288
# Arab World    7458.647059   7645.682856   7774.207360   8094.149842
#
#                      1997          1998  ...          2010          2011  \
# Country                                  ...
# ...

# %%
df_gdp.dtypes
# Out:
# Country Code     object
# 1990            float64
# 1991            float64
# 1992            float64
# 1993            float64
# 1994            float64
# 1995            float64
# 1996            float64
# 1997            float64
# 1998            float64
# 1999            float64
# 2000            float64
# 2001            float64
# 2002            float64
# 2003            float64
# 2004            float64
# 2005            float64
# 2006            float64
# 2007            float64
# 2008            float64
# 2009            float64
# 2010            float64
# 2011            float64
# 2012            float64
# 2013            float64
# 2014            float64
# 2015            float64
# 2016            float64
# 2017            float64
# 2018            float64
# 2019            float64
# dtype: object

# %%
df_gdp['2018'].mean()
# Out:
# 21134.599620759305

# %%
improved_df_gdp=df_gdp.iloc[:,-2]

# %%
improved_df_gdp
# Out:
# Country
# Aruba                    NaN
# Afghanistan      1955.006208
# Angola           6452.355165
# Albania         13364.155400
# Arab World      17570.137600
#                     ...
# Kosovo          11348.363450
# Yemen, Rep.      2575.126385
# South Africa    13686.882360
# Zambia           4223.906936
# Zimbabwe         3029.793005
# Name: 2018, Length: 260, dtype: float64

# %%
improved_df_gdp.isna().sum()
# Out:
# 29

# %%
improved_df_gdp.shape
# Out:
# (260,)

# %%
x=improved_df_gdp.drop_duplicates

# %%
x
# Out:
# <bound method Series.drop_duplicates of Country
# Aruba                    NaN
# Afghanistan      1955.006208
# Angola           6452.355165
# Albania         13364.155400
# Arab World      17570.137600
#                     ...
# Kosovo          11348.363450
# Yemen, Rep.      2575.126385
# South Africa    13686.882360
# Zambia           4223.906936
# Zimbabwe         3029.793005
# Name: 2018, Length: 260, dtype: float64>

# %%
#No duplicates in improved_df_gdp

# %%
df.shape
# Out:
# (186, 34)

# %%
y=df.drop_duplicates

# %%
y
# Out:
# <bound method DataFrame.drop_duplicates of           Country Name      WEBNAME                        Region  World Rank  \
# CountryID
# 1          Afghanistan  Afghanistan                  Asia-Pacific       152.0
# 2              Albania      Albania                        Europe        52.0
# 3              Algeria      Algeria  Middle East and North Africa       171.0
# 4               Angola       Angola            Sub-Saharan Africa       156.0
# 5            Argentina    Argentina                      Americas       148.0
# ...                ...          ...                           ...         ...
# 179          Venezuela    Venezuela                      Americas       179.0
# 180            Vietnam      Vietnam                  Asia-Pacific       128.0
# 181              Yemen        Yemen  Middle East and North Africa         NaN
# 182             Zambia       Zambia            Sub-Saharan Africa       138.0
# ...

# %%
# No duplicates in df

# %%
df.isna().sum()
# Out:
# Country Name                   0
# WEBNAME                        0
# Region                         0
# World Rank                     6
# Region Rank                    6
# 2019 Score                     6
# Property Rights                1
# Judical Effectiveness          1
# Government Integrity           1
# Tax Burden                     6
# Gov't Spending                 3
# Fiscal Health                  3
# Business Freedom               1
# Labor Freedom                  2
# Monetary Freedom               2
# Trade Freedom                  4
# Investment Freedom             2
# Financial Freedom              5
# Tariff Rate (%)                4
# Income Tax Rate (%)            3
# Corporate Tax Rate (%)         3
# Tax Burden % of GDP            7
# Gov't Expenditure % of GDP     4
# Country                        0
# Population (Millions)          0
# GDP (Billions, PPP)            1
# GDP Growth Rate (%)            2
# 5 Year GDP Growth Rate (%)     3
# ...

# %%
#very few na's in df

# %%
df.shape
# Out:
# (186, 34)

# %%
df=df.fillna(0)

# %%
improved_df_gdp=improved_df_gdp.fillna(0)
improved_df_gdp
# Out:
# Country
# Aruba           21134.600000
# Afghanistan      1955.006208
# Angola           6452.355165
# Albania         13364.155400
# Arab World      17570.137600
#                     ...
# Kosovo          11348.363450
# Yemen, Rep.      2575.126385
# South Africa    13686.882360
# Zambia           4223.906936
# Zimbabwe         3029.793005
# Name: 2018, Length: 260, dtype: float64

# %%
df_gdp.head()
# Out:
#             Country Code          1990          1991          1992  \
# Country
# Aruba                ABW  24101.109430  25870.755940  26533.343900
# Afghanistan          AFG   7319.100000   7515.800000   7689.100000
# Angola               AGO   3089.683369   3120.356148   2908.160798
# Albania              ALB   2549.473022   1909.114038   1823.307673
# Arab World           ARB   6808.206995   6872.273195   7255.328362
#
#                      1993          1994          1995          1996  \
# Country
# Aruba        27430.752400  28656.520210  28648.990020  28499.089430
# Afghanistan   7874.100000   8094.000000   8593.100000   8933.700000
# Angola        2190.768160   2195.532289   2496.199493   2794.896906
# Albania       2057.449657   2289.873135   2665.764906   2980.066288
# Arab World    7458.647059   7645.682856   7774.207360   8094.149842
#
#                      1997          1998  ...          2010          2011  \
# Country                                  ...
# ...

# %%
df_gdp['2018'].mean()
# Out:
# 21134.599663059213

# %%
t=df_gdp.loc[df_gdp["Country Code"]=="ABW"]

# %%
t
# Out:
#          Country Code         1990         1991        1992        1993  \
# Country
# Aruba             ABW  24101.10943  25870.75594  26533.3439  27430.7524
#
#                  1994         1995         1996         1997         1998  \
# Country
# Aruba     28656.52021  28648.99002  28499.08943  30215.94923  30512.68391
#
#           ...         2010         2011         2012         2013  \
# Country   ...
# Aruba     ...  33732.84745  35492.61849  35498.98209  37419.89282
#
#                  2014         2015         2016         2017     2018  2019
# Country
# Aruba     38223.37226  38249.05487  38390.27165  39454.62983  21134.6   NaN
#
# [1 rows x 31 columns]

# %%
df_gdp_mean=df_gdp.fillna(df_gdp.mean(axis=0).round(1), inplace=True)

# %%
improved_df_gdp=df_gdp.iloc[:,-2]

# %%
improved_df_gdp.isna().sum()
# Out:
# 0

# %%
improved_df_gdp.tail(30)
# Out:
# Country
# Latin America & the Caribbean (IDA & IBRD countries)    16510.958750
# Timor-Leste                                              7658.434996
# Middle East & North Africa (IDA & IBRD countries)       21134.600000
# Tonga                                                    6419.561778
# South Asia (IDA & IBRD)                                  7084.490975
# Sub-Saharan Africa (IDA & IBRD countries)                3987.503987
# Trinidad and Tobago                                     32014.783130
# Tunisia                                                 12502.820190
# Turkey                                                  28068.859410
# Tuvalu                                                   4049.564380
# Tanzania                                                 3240.262937
# Uganda                                                   2038.073892
# Ukraine                                                  9249.462135
# ...

# %%
df_gdp.head(30)
# Out:
#                        Country Code          1990          1991          1992  \
# Country
# Aruba                           ABW  24101.109430  25870.755940  26533.343900
# Afghanistan                     AFG   7319.100000   7515.800000   7689.100000
# Angola                          AGO   3089.683369   3120.356148   2908.160798
# Albania                         ALB   2549.473022   1909.114038   1823.307673
# Arab World                      ARB   6808.206995   6872.273195   7255.328362
# United Arab Emirates            ARE  72906.520120  71753.729560  71567.827520
# Argentina                       ARG   7380.115031   8210.643432   8942.569853
# Armenia                         ARM   2428.558960   2237.752728   1356.210786
# Antigua and Barbuda             ATG  11326.702620  11806.234410  12005.986790
# Australia                       AUS  17329.706610  17790.980140  18189.378740
# Austria                         AUT  19442.312040  20585.019310  21259.636750
# ...

# %%
#many of the countrys that have missing values seem to be small dependcies and may not be in main dataset. Also gdp data set includes regions in countrys

# %%
df.shape
# Out:
# (186, 34)

# %%
df_gdp.shape
# Out:
# (260, 31)

# %%
improved_df_gdp.shape
# Out:
# (260,)

# %%
df_gdp.head(5)
# Out:
#             Country Code          1990          1991          1992  \
# Country
# Aruba                ABW  24101.109430  25870.755940  26533.343900
# Afghanistan          AFG   7319.100000   7515.800000   7689.100000
# Angola               AGO   3089.683369   3120.356148   2908.160798
# Albania              ALB   2549.473022   1909.114038   1823.307673
# Arab World           ARB   6808.206995   6872.273195   7255.328362
#
#                      1993          1994          1995          1996  \
# Country
# Aruba        27430.752400  28656.520210  28648.990020  28499.089430
# Afghanistan   7874.100000   8094.000000   8593.100000   8933.700000
# Angola        2190.768160   2195.532289   2496.199493   2794.896906
# Albania       2057.449657   2289.873135   2665.764906   2980.066288
# Arab World    7458.647059   7645.682856   7774.207360   8094.149842
#
#                      1997          1998  ...          2010          2011  \
# Country                                  ...
# ...

# %%
df_gdp_ri = df_gdp.reset_index()

# %%
df_gdp_ri_improved=df_gdp_ri.iloc[:,-2]

# %%
df_gdp_ri_improved
# Out:
# 0      21134.600000
# 1       1955.006208
# 2       6452.355165
# 3      13364.155400
# 4      17570.137600
#            ...
# 255    11348.363450
# 256     2575.126385
# 257    13686.882360
# 258     4223.906936
# 259     3029.793005
# Name: 2018, Length: 260, dtype: float64

# %%
df_gdp_ri.head(1)
# Out:
#   Country  Country Code         1990         1991        1992        1993  \
# 0    Aruba          ABW  24101.10943  25870.75594  26533.3439  27430.7524
#
#           1994         1995         1996         1997  ...         2010  \
# 0  28656.52021  28648.99002  28499.08943  30215.94923  ...  33732.84745
#
#           2011         2012         2013         2014         2015  \
# 0  35492.61849  35498.98209  37419.89282  38223.37226  38249.05487
#
#           2016         2017     2018  2019
# 0  38390.27165  39454.62983  21134.6   NaN
#
# [1 rows x 32 columns]

# %%
df_gdp_ri.columns
# Out:
# Index(['Country ', 'Country Code', '1990', '1991', '1992', '1993', '1994',
#        '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003',
#        '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012',
#        '2013', '2014', '2015', '2016', '2017', '2018', '2019'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['Country Name', 'WEBNAME', 'Region', 'World Rank', 'Region Rank',
#        '2019 Score', 'Property Rights', 'Judical Effectiveness',
#        'Government Integrity', 'Tax Burden', 'Gov't Spending', 'Fiscal Health',
#        'Business Freedom', 'Labor Freedom', 'Monetary Freedom',
#        'Trade Freedom', 'Investment Freedom ', 'Financial Freedom',
#        'Tariff Rate (%)', 'Income Tax Rate (%)', 'Corporate Tax Rate (%)',
#        'Tax Burden % of GDP', 'Gov't Expenditure % of GDP ', 'Country',
#        'Population (Millions)', 'GDP (Billions, PPP)', 'GDP Growth Rate (%)',
#        '5 Year GDP Growth Rate (%)', 'GDP per Capita (PPP)',
#        'Unemployment (%)', 'Inflation (%)', 'FDI Inflow (Millions)',
#        'Public Debt (% of GDP)', 'GDP per Capita no Dollar'],
#       dtype='object')

# %%
result =pd.concat([df, df_gdp_ri_improved], axis=1)

# %%
result
# Out:
#     Country Name      WEBNAME                        Region  World Rank  \
# 0            NaN          NaN                           NaN         NaN
# 1    Afghanistan  Afghanistan                  Asia-Pacific       152.0
# 2        Albania      Albania                        Europe        52.0
# 3        Algeria      Algeria  Middle East and North Africa       171.0
# 4         Angola       Angola            Sub-Saharan Africa       156.0
# ..           ...          ...                           ...         ...
# 255          NaN          NaN                           NaN         NaN
# 256          NaN          NaN                           NaN         NaN
# 257          NaN          NaN                           NaN         NaN
# 258          NaN          NaN                           NaN         NaN
# 259          NaN          NaN                           NaN         NaN
#
#      Region Rank  2019 Score  Property Rights  Judical Effectiveness  \
# ...

# %%
result.loc[result["Country Name"]=="Germany"]
# Out:
#    Country Name  WEBNAME  Region  World Rank  Region Rank  2019 Score  \
# 62      Germany  Germany  Europe        24.0         14.0        73.5
#
#     Property Rights  Judical Effectiveness  Government Integrity  Tax Burden  \
# 62             79.9                   75.4                  81.3        60.8
#
#     ...  GDP (Billions, PPP)  GDP Growth Rate (%)  5 Year GDP Growth Rate (%)  \
# 62  ...            $4,170.8                   2.5                         1.7
#
#     GDP per Capita (PPP)  Unemployment (%)  Inflation (%)  \
# 62               $50,425               3.8            1.7
#
#     FDI Inflow (Millions)  Public Debt (% of GDP)  GDP per Capita no Dollar  \
# 62              34,726.30                    64.1                     50425
#
#            2018
# 62  46207.32351
#
# [1 rows x 35 columns]

# %%
df_gdp.loc[df_gdp["Country Code"]=="ABW"]
# Out:
#          Country Code         1990         1991        1992        1993  \
# Country
# Aruba             ABW  24101.10943  25870.75594  26533.3439  27430.7524
#
#                  1994         1995         1996         1997         1998  \
# Country
# Aruba     28656.52021  28648.99002  28499.08943  30215.94923  30512.68391
#
#           ...         2010         2011         2012         2013  \
# Country   ...
# Aruba     ...  33732.84745  35492.61849  35498.98209  37419.89282
#
#                  2014         2015         2016         2017     2018  2019
# Country
# Aruba     38223.37226  38249.05487  38390.27165  39454.62983  21134.6   NaN
#
# [1 rows x 31 columns]

# %%
result2=df.merge(df_gdp, how='left',left_on='Country Name', right_index=True)

# %%
result2
# Out:
#           Country Name      WEBNAME                        Region  World Rank  \
# CountryID
# 1          Afghanistan  Afghanistan                  Asia-Pacific       152.0
# 2              Albania      Albania                        Europe        52.0
# 3              Algeria      Algeria  Middle East and North Africa       171.0
# 4               Angola       Angola            Sub-Saharan Africa       156.0
# 5            Argentina    Argentina                      Americas       148.0
# ...                ...          ...                           ...         ...
# 179          Venezuela    Venezuela                      Americas       179.0
# 180            Vietnam      Vietnam                  Asia-Pacific       128.0
# 181              Yemen        Yemen  Middle East and North Africa         0.0
# 182             Zambia       Zambia            Sub-Saharan Africa       138.0
# 183           Zimbabwe     Zimbabwe            Sub-Saharan Africa       175.0
#
# ...

# %%
result2.loc[result2["Country Name"]=="Germany"]
# Out:
#           Country Name  WEBNAME  Region  World Rank  Region Rank  2019 Score  \
# CountryID
# 62             Germany  Germany  Europe        24.0         14.0        73.5
#
#            Property Rights  Judical Effectiveness  Government Integrity  \
# CountryID
# 62                    79.9                   75.4                  81.3
#
#            Tax Burden  ...         2010         2011         2012  \
# CountryID              ...
# 62               60.8  ...  38949.54976  42541.53109  43359.61483
#
#                   2013         2014        2015         2016         2017  \
# CountryID
# 62         44993.89275  47011.55109  47683.7886  49516.08269  52055.30995
#
#                   2018  2019
# CountryID
# 62         53074.54012   NaN
#
# [1 rows x 65 columns]

# %%
result2.loc[result2["Country Name"]=="Spain"]
# Out:
#           Country Name WEBNAME  Region  World Rank  Region Rank  2019 Score  \
# CountryID
# 152              Spain   Spain  Europe        57.0         28.0        65.7
#
#            Property Rights  Judical Effectiveness  Government Integrity  \
# CountryID
# 152                   72.9                   51.4                  51.9
#
#            Tax Burden  ...         2010         2011      2012        2013  \
# CountryID              ...
# 152              62.3  ...  31680.18539  31867.97324  31720.12  32434.0032
#
#                   2014         2015         2016         2017         2018  \
# CountryID
# 152        33525.74063  34912.47613  36554.93455  38888.73547  39715.43906
#
#            2019
# CountryID
# 152         NaN
#
# [1 rows x 65 columns]

# %%
improved_df_gdp.isna().sum()
# Out:
# 0

# %%
improved_df_gdp
# Out:
# Country
# Aruba           21134.600000
# Afghanistan      1955.006208
# Angola           6452.355165
# Albania         13364.155400
# Arab World      17570.137600
#                     ...
# Kosovo          11348.363450
# Yemen, Rep.      2575.126385
# South Africa    13686.882360
# Zambia           4223.906936
# Zimbabwe         3029.793005
# Name: 2018, Length: 260, dtype: float64

# %%
result3=df.merge(improved_df_gdp, how='left',left_on='Country Name', right_index=True)

# %%
result3
# Out:
#           Country Name      WEBNAME                        Region  World Rank  \
# CountryID
# 1          Afghanistan  Afghanistan                  Asia-Pacific       152.0
# 2              Albania      Albania                        Europe        52.0
# 3              Algeria      Algeria  Middle East and North Africa       171.0
# 4               Angola       Angola            Sub-Saharan Africa       156.0
# 5            Argentina    Argentina                      Americas       148.0
# ...                ...          ...                           ...         ...
# 179          Venezuela    Venezuela                      Americas       179.0
# 180            Vietnam      Vietnam                  Asia-Pacific       128.0
# 181              Yemen        Yemen  Middle East and North Africa         0.0
# 182             Zambia       Zambia            Sub-Saharan Africa       138.0
# 183           Zimbabwe     Zimbabwe            Sub-Saharan Africa       175.0
#
# ...

# %%
result3['2018'].isna().sum()
# Out:
# 25

# %%
result3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 186 entries, 1 to 183
# Data columns (total 35 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Country Name                 186 non-null    object
#  1   WEBNAME                      186 non-null    object
#  2   Region                       186 non-null    object
#  3   World Rank                   186 non-null    float64
#  4   Region Rank                  186 non-null    float64
#  5   2019 Score                   186 non-null    float64
#  6   Property Rights              186 non-null    float64
#  7   Judical Effectiveness        186 non-null    float64
#  8   Government Integrity         186 non-null    float64
#  9   Tax Burden                   186 non-null    float64
#  10  Gov't Spending               186 non-null    float64
#  11  Fiscal Health                186 non-null    float64
# ...

# %%
result_group5=result3.groupby(['Region'])["2018"].agg(['mean','median'])

# %%
result_group5
# Out:
#                                       mean        median
# Region
# Americas                      17520.016603  15012.930270
# Asia-Pacific                  17747.329975   8951.085654
# Europe                        37694.965734  35717.567780
# Middle East and North Africa  39760.387547  30341.666895
# Sub-Saharan Africa             7091.225556   3240.262937

# %%
for x in result3:
    print(x)
# Out:
# Country Name
# WEBNAME
# Region
# World Rank
# Region Rank
# 2019 Score
# Property Rights
# Judical Effectiveness
# Government Integrity
# Tax Burden
# Gov't Spending
# Fiscal Health
# Business Freedom
# Labor Freedom
# Monetary Freedom
# Trade Freedom
# Investment Freedom
# Financial Freedom
# Tariff Rate (%)
# Income Tax Rate (%)
# Corporate Tax Rate (%)
# Tax Burden % of GDP
# Gov't Expenditure % of GDP
# Country
# Population (Millions)
# GDP (Billions, PPP)
# GDP Growth Rate (%)
# 5 Year GDP Growth Rate (%)
# GDP per Capita (PPP)
# Unemployment (%)
# Inflation (%)
# FDI Inflow (Millions)
# Public Debt (% of GDP)
# GDP per Capita no Dollar
# 2018

# %%
for index, row in result3.head(2).iterrows():
    print(index)
    print(row)
# Out:
# 1
# Country Name                    Afghanistan
# WEBNAME                         Afghanistan
# Region                         Asia-Pacific
# World Rank                            152.0
# Region Rank                            39.0
# 2019 Score                             51.5
# Property Rights                        19.6
# Judical Effectiveness                  29.6
# Government Integrity                   25.2
# Tax Burden                             91.7
# Gov't Spending                         80.3
# Fiscal Health                          99.3
# Business Freedom                       49.2
# Labor Freedom                          60.4
# Monetary Freedom                       76.7
# Trade Freedom                          66.0
# Investment Freedom                     10.0
# Financial Freedom                      10.0
# Tariff Rate (%)                         7.0
# Income Tax Rate (%)                    20.0
# Corporate Tax Rate (%)                 20.0
# ...

# %%
for index, row in result3.head().iterrows():
    print(f"{row[1]} has a propert rights scorce of {row[6]} which partly explains its GDP of {row[25]} billion")
# Out:
# Afghanistan has a propert rights scorce of 19.6 which partly explains its GDP of $69.6  billion
# Albania has a propert rights scorce of 54.8 which partly explains its GDP of $36.0  billion
# Algeria has a propert rights scorce of 31.6 which partly explains its GDP of $632.9  billion
# Angola has a propert rights scorce of 35.9 which partly explains its GDP of $190.3  billion
# Argentina has a propert rights scorce of 47.8 which partly explains its GDP of $920.2  billion

# %%
def region_west(result3):
    if result3 in ['Europe','Americas']:
        return 'West'
    else:
        return "Not West"

# %%
result3['west'] = result3['Region'].apply(region_west)
result3.tail()
# Out:
#           Country Name    WEBNAME                        Region  World Rank  \
# CountryID
# 179          Venezuela  Venezuela                      Americas       179.0
# 180            Vietnam    Vietnam                  Asia-Pacific       128.0
# 181              Yemen      Yemen  Middle East and North Africa         0.0
# 182             Zambia     Zambia            Sub-Saharan Africa       138.0
# 183           Zimbabwe   Zimbabwe            Sub-Saharan Africa       175.0
#
#            Region Rank  2019 Score  Property Rights  Judical Effectiveness  \
# CountryID
# 179               32.0        25.9              7.6                   13.1
# 180               30.0        55.3             49.8                   40.3
# 181                0.0         0.0             19.6                   22.2
# 182               27.0        53.6             45.0                   35.6
# 183               45.0        40.4             29.7                   24.8
#
# ...

# %%
result3['Ability to service National Debt']=result3['Tax Burden % of GDP']/result3['Public Debt (% of GDP)']

# %%
result3['Ability to service National Debt']
# Out:
# CountryID
# 1      0.684932
# 2      0.349719
# 3      0.949612
# 4      0.315467
# 5      0.585551
#          ...
# 179    0.426934
# 180    0.309278
# 181    0.000000
# 182    0.287781
# 183    0.284439
# Name: Ability to service National Debt, Length: 186, dtype: float64

# %%
# This shows a nations ability to pay its national debt

# %%
result3[result3['Ability to service National Debt']>0.6]
# Out:
#                                       Country Name                  WEBNAME  \
# CountryID
# 1                                      Afghanistan              Afghanistan
# 3                                          Algeria                  Algeria
# 7                                        Australia                Australia
# 19                                         Bolivia                  Bolivia
# 20                          Bosnia and Herzegovina        BosniaHerzegovina
# 21                                        Botswana                 Botswana
# 186                              Brunei Darussalam                  Brunei
# 23                                        Bulgaria                 Bulgaria
# 33                                           Chile                    Chile
# 37         Congo, Democratic Republic of the Congo  DemcoraticRepublicCongo
# 42                                            Cuba                     Cuba
# ...
