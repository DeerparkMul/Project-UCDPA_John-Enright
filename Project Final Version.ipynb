# %%
pip install mysql-connector-python
# Out:
# Requirement already satisfied: mysql-connector-python in c:\users\dr\anaconda3\lib\site-packages (8.0.28)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: protobuf>=3.0.0 in c:\users\dr\anaconda3\lib\site-packages (from mysql-connector-python) (3.19.4)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import mysql.connector

# %%
mydb = mysql.connector.connect(
    host="127.0.0.1",
    user="root",
    password="password1234!",
    database='vendas')

# %%
mycursor = mydb.cursor()
mycursor

# %%
mycursor.execute("Select * from vendas.covidpercapita")

# %%
myresults = mycursor.fetchall()
type(myresults)
# Out:
# list

# %%
myresults[1]
# Out:
# ('United States of America', 294)

# %%
df_SQL = []   # Initialising empty list
for x in myresults:    # for loop to append each entry to a new list of lists
    df_SQL.append(list(x)) 
df_SQL = pd.DataFrame(df_SQL)  # Convert list of lists into a DataFrame
df_SQL.columns = mycursor.column_names # Add the columns names
df_SQL.head()
# Out:
#                     ï»¿Name  Deaths - cumulative total per 100000 population
# 0                    Global                                               79
# 1  United States of America                                              294
# 2                     India                                               38
# 3                    Brazil                                              311
# 4                    France                                              214

# %%
df_SQL.shape
# Out:
# (238, 2)

# %%
e=df_SQL.drop_duplicates

# %%
e
# Out:
# <bound method DataFrame.drop_duplicates of                       ï»¿Name  Deaths - cumulative total per 100000 population
# 0                      Global                                               79
# 1    United States of America                                              294
# 2                       India                                               38
# 3                      Brazil                                              311
# 4                      France                                              214
# ..                        ...                                              ...
# 233          Pitcairn Islands                                                0
# 234              Saint Helena                                                0
# 235                   Tokelau                                                0
# 236              Turkmenistan                                                0
# 237                    Tuvalu                                                0
#
# [238 rows x 2 columns]>

# %%
df= pd.read_csv('C:/Users/DR/Desktop/moving computer/UCD CERT in DATA/economic_freedom_index2019_data.csv', index_col=0)

# %%
df.head()
# Out:
#           Country Name      WEBNAME                        Region  World Rank  \
# CountryID
# 1          Afghanistan  Afghanistan                  Asia-Pacific       152.0
# 2              Albania      Albania                        Europe        52.0
# 3              Algeria      Algeria  Middle East and North Africa       171.0
# 4               Angola       Angola            Sub-Saharan Africa       156.0
# 5            Argentina    Argentina                      Americas       148.0
#
#            Region Rank  2019 Score  Property Rights  Judical Effectiveness  \
# CountryID
# 1                 39.0        51.5             19.6                   29.6
# 2                 27.0        66.5             54.8                   30.6
# 3                 14.0        46.2             31.6                   36.2
# 4                 33.0        50.6             35.9                   26.6
# 5                 26.0        52.2             47.8                   44.5
#
#            Government Integrity  Tax Burden  ...      Country  \
# CountryID                                    ...
# 1                          25.2        91.7  ...  Afghanistan
# 2                          40.4        86.3  ...      Albania
# 3                          28.9        76.4  ...      Algeria
# 4                          20.5        83.9  ...       Angola
# 5                          33.5        69.3  ...    Argentina
#
#            Population (Millions)  GDP (Billions, PPP)  GDP Growth Rate (%)  \
# CountryID
# 1                           35.5               $69.6                   2.5
# 2                            2.9               $36.0                   3.9
# 3                           41.5              $632.9                   2.0
# 4                           28.2              $190.3                   0.7
# 5                           44.1              $920.2                   2.9
#
#            5 Year GDP Growth Rate (%)  GDP per Capita (PPP)  Unemployment (%)  \
# CountryID
# 1                                 2.9                $1,958               8.8
# 2                                 2.5               $12,507              13.9
# 3                                 3.1               $15,237                10
# 4                                 2.9                $6,753               8.2
# 5                                 0.7               $20,876               8.7
#
#            Inflation (%)  FDI Inflow (Millions)  Public Debt (% of GDP)
# CountryID
# 1                    5.0                   53.9                     7.3
# 2                    2.0               1,119.10                    71.2
# 3                    5.6               1,203.00                    25.8
# 4                   31.7              -2,254.50                    65.3
# 5                   25.7              11,857.00                    52.6
#
# [5 rows x 33 columns]

# %%
df.tail()
# Out:
#           Country Name    WEBNAME                        Region  World Rank  \
# CountryID
# 179          Venezuela  Venezuela                      Americas       179.0
# 180            Vietnam    Vietnam                  Asia-Pacific       128.0
# 181              Yemen      Yemen  Middle East and North Africa         NaN
# 182             Zambia     Zambia            Sub-Saharan Africa       138.0
# 183           Zimbabwe   Zimbabwe            Sub-Saharan Africa       175.0
#
#            Region Rank  2019 Score  Property Rights  Judical Effectiveness  \
# CountryID
# 179               32.0        25.9              7.6                   13.1
# 180               30.0        55.3             49.8                   40.3
# 181                NaN         NaN             19.6                   22.2
# 182               27.0        53.6             45.0                   35.6
# 183               45.0        40.4             29.7                   24.8
#
#            Government Integrity  Tax Burden  ...    Country  \
# CountryID                                    ...
# 179                         7.9        74.7  ...  Venezuela
# 180                        34.0        79.7  ...    Vietnam
# 181                        20.3         NaN  ...      Yemen
# 182                        32.3        72.3  ...     Zambia
# 183                        15.8        62.3  ...   Zimbabwe
#
#            Population (Millions)  GDP (Billions, PPP)  GDP Growth Rate (%)  \
# CountryID
# 179                         31.4              $380.7                 -14.0
# 180                         93.6              $647.4                   6.8
# 181                           30               $38.6                 -13.8
# 182                         17.2               $68.9                   3.6
# 183                         14.9               $34.0                   3.0
#
#            5 Year GDP Growth Rate (%)  GDP per Capita (PPP)  Unemployment (%)  \
# CountryID
# 179                              -7.8               $12,114               7.7
# 180                               6.2                $6,913               2.1
# 181                             -16.1                $1,287                14
# 182                               4.0                $3,996               7.8
# 183                               2.6                $2,283                 5
#
#            Inflation (%)  FDI Inflow (Millions)  Public Debt (% of GDP)
# CountryID
# 179               1087.5                    -68                    34.9
# 180                  3.5              14,100.00                    58.2
# 181                  4.9                 -269.9                   141.0
# 182                  6.6               1,091.20                    62.2
# 183                  1.3                  289.4                    78.4
#
# [5 rows x 33 columns]

# %%
df.describe()
# Out:
#        World Rank  Region Rank  2019 Score  Property Rights  \
# count  180.000000   180.000000  180.000000       185.000000
# mean    90.500000    20.538889   60.768333        52.327568
# std     52.105662    12.738611   11.255725        19.608526
# min      1.000000     1.000000    5.900000         7.600000
# 25%     45.750000     9.750000   53.950000        37.000000
# 50%     90.500000    19.500000   60.750000        50.100000
# 75%    135.250000    31.000000   67.800000        65.900000
# max    180.000000    47.000000   90.200000        97.400000
#
#        Judical Effectiveness  Government Integrity  Tax Burden  \
# count             185.000000            185.000000  180.000000
# mean               44.899459             41.470270   77.212778
# std                18.104745             19.793193   13.208314
# min                 5.000000              7.900000    0.000000
# 25%                31.000000             27.200000   70.975000
# 50%                42.900000             35.500000   78.050000
# 75%                54.700000             50.300000   85.425000
# max                92.400000             96.700000   99.800000
#
#        Gov't Spending  Fiscal Health  Business Freedom  ...  \
# count      183.000000     183.000000        185.000000  ...
# mean        64.203825      65.996721         63.514054  ...
# std         23.150984      31.764160         15.799326  ...
# min          0.000000       0.000000          5.000000  ...
# 25%         51.700000      39.900000         54.100000  ...
# 50%         68.800000      80.300000         64.300000  ...
# 75%         82.600000      91.450000         75.000000  ...
# max         96.600000     100.000000         96.400000  ...
#
#        Financial Freedom  Tariff Rate (%)  Income Tax Rate (%)  \
# count         181.000000       182.000000           183.000000
# mean           48.784530         5.986813            28.183060
# std            19.483982         5.533568            13.374339
# min             0.000000         0.000000             0.000000
# 25%            30.000000         2.000000            20.000000
# 50%            50.000000         4.300000            30.000000
# 75%            60.000000         8.775000            35.000000
# max            90.000000        50.000000            60.000000
#
#        Corporate Tax Rate (%)  Tax Burden % of GDP  \
# count              183.000000           179.000000
# mean                23.891257            22.157542
# std                  8.858207            10.152671
# min                  0.000000             1.600000
# 25%                 20.000000            14.250000
# 50%                 25.000000            20.700000
# 75%                 30.000000            29.850000
# max                 50.000000            47.000000
#
#        Gov't Expenditure % of GDP   GDP Growth Rate (%)  \
# count                   182.000000           184.000000
# mean                     33.863736             3.470109
# std                      15.476484             5.835732
# min                      10.600000           -14.000000
# 25%                      24.675000             1.800000
# 50%                      32.350000             3.200000
# 75%                      40.225000             4.650000
# max                     139.200000            70.800000
#
#        5 Year GDP Growth Rate (%)  Inflation (%)  Public Debt (% of GDP)
# count                  183.000000     182.000000              182.000000
# mean                     2.984153      10.586264               56.469231
# std                      2.926503      80.507501               34.163855
# min                    -16.100000      -0.900000                0.000000
# 25%                      1.900000       1.300000               34.950000
# 50%                      3.000000       2.750000               49.900000
# 75%                      4.450000       5.450000               70.125000
# max                      9.900000    1087.500000              236.400000
#
# [8 rows x 24 columns]

# %%
df["Tax Burden"]
# Out:
# CountryID
# 1      91.7
# 2      86.3
# 3      76.4
# 4      83.9
# 5      69.3
#        ...
# 179    74.7
# 180    79.7
# 181     NaN
# 182    72.3
# 183    62.3
# Name: Tax Burden, Length: 186, dtype: float64

# %%
list_of_columns = ["Property Rights", "Gov't Spending"]
df[list_of_columns]
# Out:
#            Property Rights  Gov't Spending
# CountryID
# 1                     19.6            80.3
# 2                     54.8            73.9
# 3                     31.6            48.7
# 4                     35.9            80.7
# 5                     47.8            49.5
# ...                    ...             ...
# 179                    7.6            58.1
# 180                   49.8            74.1
# 181                   19.6            83.7
# 182                   45.0            80.1
# 183                   29.7            74.5
#
# [186 rows x 2 columns]

# %%
df.loc[df["Country Name"]=="Australia"]
# Out:
#           Country Name    WEBNAME        Region  World Rank  Region Rank  \
# CountryID
# 7            Australia  Australia  Asia-Pacific         5.0          4.0
#
#            2019 Score  Property Rights  Judical Effectiveness  \
# CountryID
# 7                80.9             79.1                   86.5
#
#            Government Integrity  Tax Burden  ...    Country  \
# CountryID                                    ...
# 7                          79.9        62.8  ...  Australia
#
#            Population (Millions)  GDP (Billions, PPP)  GDP Growth Rate (%)  \
# CountryID
# 7                           24.8            $1,246.5                   2.3
#
#            5 Year GDP Growth Rate (%)  GDP per Capita (PPP)  Unemployment (%)  \
# CountryID
# 7                                 2.4               $50,334               5.6
#
#            Inflation (%)  FDI Inflow (Millions)  Public Debt (% of GDP)
# CountryID
# 7                    2.0              46,368.00                    41.6
#
# [1 rows x 33 columns]

# %%
df1=df[0:2]

# %%
df1
# Out:
#           Country Name      WEBNAME        Region  World Rank  Region Rank  \
# CountryID
# 1          Afghanistan  Afghanistan  Asia-Pacific       152.0         39.0
# 2              Albania      Albania        Europe        52.0         27.0
#
#            2019 Score  Property Rights  Judical Effectiveness  \
# CountryID
# 1                51.5             19.6                   29.6
# 2                66.5             54.8                   30.6
#
#            Government Integrity  Tax Burden  ...      Country  \
# CountryID                                    ...
# 1                          25.2        91.7  ...  Afghanistan
# 2                          40.4        86.3  ...      Albania
#
#            Population (Millions)  GDP (Billions, PPP)  GDP Growth Rate (%)  \
# CountryID
# 1                           35.5               $69.6                   2.5
# 2                            2.9               $36.0                   3.9
#
#            5 Year GDP Growth Rate (%)  GDP per Capita (PPP)  Unemployment (%)  \
# CountryID
# 1                                 2.9                $1,958               8.8
# 2                                 2.5               $12,507              13.9
#
#            Inflation (%)  FDI Inflow (Millions)  Public Debt (% of GDP)
# CountryID
# 1                    5.0                   53.9                     7.3
# 2                    2.0               1,119.10                    71.2
#
# [2 rows x 33 columns]

# %%
df1["World Rank"] == "Region Rank"
# Out:
# CountryID
# 1    False
# 2    False
# Name: World Rank, dtype: bool

# %%
df1["World Rank"] < 100
# Out:
# CountryID
# 1    False
# 2     True
# Name: World Rank, dtype: bool

# %%
df.isna().sum()
# Out:
# Country Name                   0
# WEBNAME                        0
# Region                         0
# World Rank                     6
# Region Rank                    6
# 2019 Score                     6
# Property Rights                1
# Judical Effectiveness          1
# Government Integrity           1
# Tax Burden                     6
# Gov't Spending                 3
# Fiscal Health                  3
# Business Freedom               1
# Labor Freedom                  2
# Monetary Freedom               2
# Trade Freedom                  4
# Investment Freedom             2
# Financial Freedom              5
# Tariff Rate (%)                4
# Income Tax Rate (%)            3
# Corporate Tax Rate (%)         3
# Tax Burden % of GDP            7
# Gov't Expenditure % of GDP     4
# Country                        0
# Population (Millions)          0
# GDP (Billions, PPP)            1
# GDP Growth Rate (%)            2
# 5 Year GDP Growth Rate (%)     3
# GDP per Capita (PPP)           2
# Unemployment (%)               5
# Inflation (%)                  4
# FDI Inflow (Millions)          5
# Public Debt (% of GDP)         4
# dtype: int64

# %%
df.shape
# Out:
# (186, 33)

# %%
dfregion=df.groupby('Region').mean()

# %%
df.groupby('Region').median()
# Out:
#                               World Rank  Region Rank  2019 Score  \
# Region
# Americas                            80.5         16.5       62.20
# Asia-Pacific                       105.0         22.0       57.80
# Europe                              45.0         22.5       67.95
# Middle East and North Africa        89.0          7.5       60.90
# Sub-Saharan Africa                 134.0         24.0       54.00
#
#                               Property Rights  Judical Effectiveness  \
# Region
# Americas                                49.15                  37.75
# Asia-Pacific                            49.90                  42.50
# Europe                                  70.65                  51.75
# Middle East and North Africa            51.05                  45.20
# Sub-Saharan Africa                      35.85                  34.40
#
#                               Government Integrity  Tax Burden  \
# Region
# Americas                                     33.35        77.1
# Asia-Pacific                                 36.40        84.0
# Europe                                       48.80        75.6
# Middle East and North Africa                 35.95        91.6
# Sub-Saharan Africa                           28.10        76.2
#
#                               Gov't Spending  Fiscal Health  Business Freedom  \
# Region
# Americas                                75.5          79.75             64.50
# Asia-Pacific                            71.7          82.40             67.30
# Europe                                  46.4          88.10             75.10
# Middle East and North Africa            62.7          20.00             64.05
# Sub-Saharan Africa                      79.4          62.30             53.30
#
#                               ...  Financial Freedom  Tariff Rate (%)  \
# Region                        ...
# Americas                      ...               50.0             6.20
# Asia-Pacific                  ...               40.0             4.00
# Europe                        ...               70.0             2.00
# Middle East and North Africa  ...               60.0             4.05
# Sub-Saharan Africa            ...               40.0             9.40
#
#                               Income Tax Rate (%)  Corporate Tax Rate (%)  \
# Region
# Americas                                     30.0                    29.0
# Asia-Pacific                                 25.0                    24.5
# Europe                                       31.8                    19.0
# Middle East and North Africa                 15.0                    20.0
# Sub-Saharan Africa                           35.0                    30.0
#
#                               Tax Burden % of GDP  \
# Region
# Americas                                    22.70
# Asia-Pacific                                15.60
# Europe                                      33.80
# Middle East and North Africa                11.35
# Sub-Saharan Africa                          16.50
#
#                               Gov't Expenditure % of GDP   \
# Region
# Americas                                            28.60
# Asia-Pacific                                        30.70
# Europe                                              42.25
# Middle East and North Africa                        36.45
# Sub-Saharan Africa                                  26.20
#
#                               GDP Growth Rate (%)  5 Year GDP Growth Rate (%)  \
# Region
# Americas                                     2.20                        2.15
# Asia-Pacific                                 4.00                        3.95
# Europe                                       3.25                        2.50
# Middle East and North Africa                 2.00                        3.10
# Sub-Saharan Africa                           3.75                        3.80
#
#                               Inflation (%)  Public Debt (% of GDP)
# Region
# Americas                               3.05                    50.8
# Asia-Pacific                           3.20                    40.7
# Europe                                 1.85                    52.0
# Middle East and North Africa           2.00                    58.0
# Sub-Saharan Africa                     5.30                    53.4
#
# [5 rows x 24 columns]

# %%
df_group2=df.groupby(['Region'])['Inflation (%)'].agg(['mean','median'])
df_group2
# Out:
#                                    mean  median
# Region
# Americas                      38.368750    3.05
# Asia-Pacific                   3.595238    3.20
# Europe                         2.579545    1.85
# Middle East and North Africa   5.417647    2.00
# Sub-Saharan Africa             7.282979    5.30

# %%
df['GDP per Capita no Dollar']=df['GDP per Capita (PPP)'].replace("[^0-9\.-]","", regex=True)

# %%
df['GDP per Capita no Dollar']
# Out:
# CountryID
# 1       1958
# 2      12507
# 3      15237
# 4       6753
# 5      20876
#        ...
# 179    12114
# 180     6913
# 181     1287
# 182     3996
# 183     2283
# Name: GDP per Capita no Dollar, Length: 186, dtype: object

# %%
df.head()
# Out:
#           Country Name      WEBNAME                        Region  World Rank  \
# CountryID
# 1          Afghanistan  Afghanistan                  Asia-Pacific       152.0
# 2              Albania      Albania                        Europe        52.0
# 3              Algeria      Algeria  Middle East and North Africa       171.0
# 4               Angola       Angola            Sub-Saharan Africa       156.0
# 5            Argentina    Argentina                      Americas       148.0
#
#            Region Rank  2019 Score  Property Rights  Judical Effectiveness  \
# CountryID
# 1                 39.0        51.5             19.6                   29.6
# 2                 27.0        66.5             54.8                   30.6
# 3                 14.0        46.2             31.6                   36.2
# 4                 33.0        50.6             35.9                   26.6
# 5                 26.0        52.2             47.8                   44.5
#
#            Government Integrity  Tax Burden  ...  Population (Millions)  \
# CountryID                                    ...
# 1                          25.2        91.7  ...                   35.5
# 2                          40.4        86.3  ...                    2.9
# 3                          28.9        76.4  ...                   41.5
# 4                          20.5        83.9  ...                   28.2
# 5                          33.5        69.3  ...                   44.1
#
#            GDP (Billions, PPP)  GDP Growth Rate (%)  \
# CountryID
# 1                       $69.6                   2.5
# 2                       $36.0                   3.9
# 3                      $632.9                   2.0
# 4                      $190.3                   0.7
# 5                      $920.2                   2.9
#
#            5 Year GDP Growth Rate (%)  GDP per Capita (PPP)  Unemployment (%)  \
# CountryID
# 1                                 2.9                $1,958               8.8
# 2                                 2.5               $12,507              13.9
# 3                                 3.1               $15,237                10
# 4                                 2.9                $6,753               8.2
# 5                                 0.7               $20,876               8.7
#
#            Inflation (%)  FDI Inflow (Millions)  Public Debt (% of GDP)  \
# CountryID
# 1                    5.0                   53.9                     7.3
# 2                    2.0               1,119.10                    71.2
# 3                    5.6               1,203.00                    25.8
# 4                   31.7              -2,254.50                    65.3
# 5                   25.7              11,857.00                    52.6
#
#            GDP per Capita no Dollar
# CountryID
# 1                              1958
# 2                             12507
# 3                             15237
# 4                              6753
# 5                             20876
#
# [5 rows x 34 columns]

# %%
df.dtypes
# Out:
# Country Name                    object
# WEBNAME                         object
# Region                          object
# World Rank                     float64
# Region Rank                    float64
# 2019 Score                     float64
# Property Rights                float64
# Judical Effectiveness          float64
# Government Integrity           float64
# Tax Burden                     float64
# Gov't Spending                 float64
# Fiscal Health                  float64
# Business Freedom               float64
# Labor Freedom                  float64
# Monetary Freedom               float64
# Trade Freedom                  float64
# Investment Freedom             float64
# Financial Freedom              float64
# Tariff Rate (%)                float64
# Income Tax Rate (%)            float64
# Corporate Tax Rate (%)         float64
# Tax Burden % of GDP            float64
# Gov't Expenditure % of GDP     float64
# Country                         object
# Population (Millions)           object
# GDP (Billions, PPP)             object
# GDP Growth Rate (%)            float64
# 5 Year GDP Growth Rate (%)     float64
# GDP per Capita (PPP)            object
# Unemployment (%)                object
# Inflation (%)                  float64
# FDI Inflow (Millions)           object
# Public Debt (% of GDP)         float64
# GDP per Capita no Dollar        object
# dtype: object

# %%
df.astype({'GDP per Capita no Dollar':float}).dtypes
# Out:
# Country Name                    object
# WEBNAME                         object
# Region                          object
# World Rank                     float64
# Region Rank                    float64
# 2019 Score                     float64
# Property Rights                float64
# Judical Effectiveness          float64
# Government Integrity           float64
# Tax Burden                     float64
# Gov't Spending                 float64
# Fiscal Health                  float64
# Business Freedom               float64
# Labor Freedom                  float64
# Monetary Freedom               float64
# Trade Freedom                  float64
# Investment Freedom             float64
# Financial Freedom              float64
# Tariff Rate (%)                float64
# Income Tax Rate (%)            float64
# Corporate Tax Rate (%)         float64
# Tax Burden % of GDP            float64
# Gov't Expenditure % of GDP     float64
# Country                         object
# Population (Millions)           object
# GDP (Billions, PPP)             object
# GDP Growth Rate (%)            float64
# 5 Year GDP Growth Rate (%)     float64
# GDP per Capita (PPP)            object
# Unemployment (%)                object
# Inflation (%)                  float64
# FDI Inflow (Millions)           object
# Public Debt (% of GDP)         float64
# GDP per Capita no Dollar       float64
# dtype: object

# %%
df_group3=df.groupby(['Region'])["GDP Growth Rate (%)"].agg(['mean','median'])
df_group3
# Out:
#                                   mean  median
# Region
# Americas                      1.587500    2.20
# Asia-Pacific                  4.332558    4.00
# Europe                        3.468182    3.25
# Middle East and North Africa  4.817647    2.00
# Sub-Saharan Africa            3.477083    3.75

# %%
df_group4=df.groupby(['Region'])["Business Freedom"].agg(['mean','median'])
df_group4
# Out:
#                                    mean  median
# Region
# Americas                      62.368750   64.50
# Asia-Pacific                  66.146512   67.30
# Europe                        74.797727   75.10
# Middle East and North Africa  63.027778   64.05
# Sub-Saharan Africa            51.758333   53.30

# %%
#This is correct graph to use to compare these two
plt.subplots(figsize=(10,5))  #This increases size
plt.scatter(df['Region'], df['Business Freedom'], s=5)
plt.show()

# %%
df_gdp= pd.read_csv('C:/Users/DR/Desktop/moving computer/UCD CERT in DATA/GDP.csv', index_col=0)

# %%
df_gdp.head()
# Out:
#             Country Code          1990          1991          1992  \
# Country
# Aruba                ABW  24101.109430  25870.755940  26533.343900
# Afghanistan          AFG           NaN           NaN           NaN
# Angola               AGO   3089.683369   3120.356148   2908.160798
# Albania              ALB   2549.473022   1909.114038   1823.307673
# Arab World           ARB   6808.206995   6872.273195   7255.328362
#
#                      1993          1994          1995          1996  \
# Country
# Aruba        27430.752400  28656.520210  28648.990020  28499.089430
# Afghanistan           NaN           NaN           NaN           NaN
# Angola        2190.768160   2195.532289   2496.199493   2794.896906
# Albania       2057.449657   2289.873135   2665.764906   2980.066288
# Arab World    7458.647059   7645.682856   7774.207360   8094.149842
#
#                      1997          1998  ...          2010          2011  \
# Country                                  ...
# Aruba        30215.949230  30512.683910  ...  33732.847450  35492.618490
# Afghanistan           NaN           NaN  ...   1637.377987   1626.764793
# Angola        2953.342709   3027.341795  ...   6230.297028   6346.395122
# Albania       2717.362124   3021.014738  ...   9628.025783  10207.752350
# Arab World    8397.515692   8797.662606  ...  14127.778020  14518.827450
#
#                      2012          2013          2014          2015  \
# Country
# Aruba        35498.982090  37419.892820  38223.372260  38249.054870
# Afghanistan   1806.763930   1874.765634   1897.525938   1886.692977
# Angola        6772.528333   6980.423038   7199.245478   7096.600615
# Albania      10526.235450  10571.010650  11259.225890  11662.030480
# Arab World   15423.465390  15824.780110  16153.244860  16501.792590
#
#                      2016          2017          2018  2019
# Country
# Aruba        38390.271650  39454.629830           NaN   NaN
# Afghanistan   1896.992520   1934.636754   1955.006208   NaN
# Angola        6756.935074   6650.584940   6452.355165   NaN
# Albania      11868.178970  12930.140030  13364.155400   NaN
# Arab World   16935.383300  17099.889390  17570.137600   NaN
#
# [5 rows x 31 columns]

# %%
df_gdp.dtypes
# Out:
# Country Code     object
# 1990            float64
# 1991            float64
# 1992            float64
# 1993            float64
# 1994            float64
# 1995            float64
# 1996            float64
# 1997            float64
# 1998            float64
# 1999            float64
# 2000            float64
# 2001            float64
# 2002            float64
# 2003            float64
# 2004            float64
# 2005            float64
# 2006            float64
# 2007            float64
# 2008            float64
# 2009            float64
# 2010            float64
# 2011            float64
# 2012            float64
# 2013            float64
# 2014            float64
# 2015            float64
# 2016            float64
# 2017            float64
# 2018            float64
# 2019            float64
# dtype: object

# %%
df_gdp['2018'].mean()
# Out:
# 21134.599620759305

# %%
improved_df_gdp=df_gdp.iloc[:,-2]

# %%
improved_df_gdp
# Out:
# Country
# Aruba                    NaN
# Afghanistan      1955.006208
# Angola           6452.355165
# Albania         13364.155400
# Arab World      17570.137600
#                     ...
# Kosovo          11348.363450
# Yemen, Rep.      2575.126385
# South Africa    13686.882360
# Zambia           4223.906936
# Zimbabwe         3029.793005
# Name: 2018, Length: 260, dtype: float64

# %%
improved_df_gdp.shape
# Out:
# (260,)

# %%
x=improved_df_gdp.drop_duplicates

# %%
x
# Out:
# <bound method Series.drop_duplicates of Country
# Aruba                    NaN
# Afghanistan      1955.006208
# Angola           6452.355165
# Albania         13364.155400
# Arab World      17570.137600
#                     ...
# Kosovo          11348.363450
# Yemen, Rep.      2575.126385
# South Africa    13686.882360
# Zambia           4223.906936
# Zimbabwe         3029.793005
# Name: 2018, Length: 260, dtype: float64>

# %%
#No duplicates in improved_df_gdp

# %%
df.shape
# Out:
# (186, 34)

# %%
y=df.drop_duplicates

# %%
y
# Out:
# <bound method DataFrame.drop_duplicates of           Country Name      WEBNAME                        Region  World Rank  \
# CountryID
# 1          Afghanistan  Afghanistan                  Asia-Pacific       152.0
# 2              Albania      Albania                        Europe        52.0
# 3              Algeria      Algeria  Middle East and North Africa       171.0
# 4               Angola       Angola            Sub-Saharan Africa       156.0
# 5            Argentina    Argentina                      Americas       148.0
# ...                ...          ...                           ...         ...
# 179          Venezuela    Venezuela                      Americas       179.0
# 180            Vietnam      Vietnam                  Asia-Pacific       128.0
# 181              Yemen        Yemen  Middle East and North Africa         NaN
# 182             Zambia       Zambia            Sub-Saharan Africa       138.0
# 183           Zimbabwe     Zimbabwe            Sub-Saharan Africa       175.0
#
#            Region Rank  2019 Score  Property Rights  Judical Effectiveness  \
# CountryID
# 1                 39.0        51.5             19.6                   29.6
# 2                 27.0        66.5             54.8                   30.6
# 3                 14.0        46.2             31.6                   36.2
# 4                 33.0        50.6             35.9                   26.6
# 5                 26.0        52.2             47.8                   44.5
# ...                ...         ...              ...                    ...
# 179               32.0        25.9              7.6                   13.1
# 180               30.0        55.3             49.8                   40.3
# 181                NaN         NaN             19.6                   22.2
# 182               27.0        53.6             45.0                   35.6
# 183               45.0        40.4             29.7                   24.8
#
#            Government Integrity  Tax Burden  ...  Population (Millions)  \
# CountryID                                    ...
# 1                          25.2        91.7  ...                   35.5
# 2                          40.4        86.3  ...                    2.9
# 3                          28.9        76.4  ...                   41.5
# 4                          20.5        83.9  ...                   28.2
# 5                          33.5        69.3  ...                   44.1
# ...                         ...         ...  ...                    ...
# 179                         7.9        74.7  ...                   31.4
# 180                        34.0        79.7  ...                   93.6
# 181                        20.3         NaN  ...                     30
# 182                        32.3        72.3  ...                   17.2
# 183                        15.8        62.3  ...                   14.9
#
#            GDP (Billions, PPP)  GDP Growth Rate (%)  \
# CountryID
# 1                       $69.6                   2.5
# 2                       $36.0                   3.9
# 3                      $632.9                   2.0
# 4                      $190.3                   0.7
# 5                      $920.2                   2.9
# ...                        ...                  ...
# 179                    $380.7                 -14.0
# 180                    $647.4                   6.8
# 181                     $38.6                 -13.8
# 182                     $68.9                   3.6
# 183                     $34.0                   3.0
#
#            5 Year GDP Growth Rate (%)  GDP per Capita (PPP)  Unemployment (%)  \
# CountryID
# 1                                 2.9                $1,958               8.8
# 2                                 2.5               $12,507              13.9
# 3                                 3.1               $15,237                10
# 4                                 2.9                $6,753               8.2
# 5                                 0.7               $20,876               8.7
# ...                               ...                   ...               ...
# 179                              -7.8               $12,114               7.7
# 180                               6.2                $6,913               2.1
# 181                             -16.1                $1,287                14
# 182                               4.0                $3,996               7.8
# 183                               2.6                $2,283                 5
#
#            Inflation (%)  FDI Inflow (Millions)  Public Debt (% of GDP)  \
# CountryID
# 1                    5.0                   53.9                     7.3
# 2                    2.0               1,119.10                    71.2
# 3                    5.6               1,203.00                    25.8
# 4                   31.7              -2,254.50                    65.3
# 5                   25.7              11,857.00                    52.6
# ...                  ...                    ...                     ...
# 179               1087.5                    -68                    34.9
# 180                  3.5              14,100.00                    58.2
# 181                  4.9                 -269.9                   141.0
# 182                  6.6               1,091.20                    62.2
# 183                  1.3                  289.4                    78.4
#
#            GDP per Capita no Dollar
# CountryID
# 1                              1958
# 2                             12507
# 3                             15237
# 4                              6753
# 5                             20876
# ...                             ...
# 179                           12114
# 180                            6913
# 181                            1287
# 182                            3996
# 183                            2283
#
# [186 rows x 34 columns]>

# %%
# No duplicates in df

# %%
df.isna().sum()
# Out:
# Country Name                   0
# WEBNAME                        0
# Region                         0
# World Rank                     6
# Region Rank                    6
# 2019 Score                     6
# Property Rights                1
# Judical Effectiveness          1
# Government Integrity           1
# Tax Burden                     6
# Gov't Spending                 3
# Fiscal Health                  3
# Business Freedom               1
# Labor Freedom                  2
# Monetary Freedom               2
# Trade Freedom                  4
# Investment Freedom             2
# Financial Freedom              5
# Tariff Rate (%)                4
# Income Tax Rate (%)            3
# Corporate Tax Rate (%)         3
# Tax Burden % of GDP            7
# Gov't Expenditure % of GDP     4
# Country                        0
# Population (Millions)          0
# GDP (Billions, PPP)            1
# GDP Growth Rate (%)            2
# 5 Year GDP Growth Rate (%)     3
# GDP per Capita (PPP)           2
# Unemployment (%)               5
# Inflation (%)                  4
# FDI Inflow (Millions)          5
# Public Debt (% of GDP)         4
# GDP per Capita no Dollar       2
# dtype: int64

# %%
df=df.fillna(0)

# %%
df.isna().sum()
# Out:
# Country Name                   0
# WEBNAME                        0
# Region                         0
# World Rank                     0
# Region Rank                    0
# 2019 Score                     0
# Property Rights                0
# Judical Effectiveness          0
# Government Integrity           0
# Tax Burden                     0
# Gov't Spending                 0
# Fiscal Health                  0
# Business Freedom               0
# Labor Freedom                  0
# Monetary Freedom               0
# Trade Freedom                  0
# Investment Freedom             0
# Financial Freedom              0
# Tariff Rate (%)                0
# Income Tax Rate (%)            0
# Corporate Tax Rate (%)         0
# Tax Burden % of GDP            0
# Gov't Expenditure % of GDP     0
# Country                        0
# Population (Millions)          0
# GDP (Billions, PPP)            0
# GDP Growth Rate (%)            0
# 5 Year GDP Growth Rate (%)     0
# GDP per Capita (PPP)           0
# Unemployment (%)               0
# Inflation (%)                  0
# FDI Inflow (Millions)          0
# Public Debt (% of GDP)         0
# GDP per Capita no Dollar       0
# dtype: int64

# %%
#very few na's in df

# %%
df.shape
# Out:
# (186, 34)

# %%
improved_df_gdp.shape
# Out:
# (260,)

# %%
result3=df.merge(improved_df_gdp, how='left',left_on='Country Name', right_index=True)

# %% [markdown]
# result3

# %%
result3
# Out:
#           Country Name      WEBNAME                        Region  World Rank  \
# CountryID
# 1          Afghanistan  Afghanistan                  Asia-Pacific       152.0
# 2              Albania      Albania                        Europe        52.0
# 3              Algeria      Algeria  Middle East and North Africa       171.0
# 4               Angola       Angola            Sub-Saharan Africa       156.0
# 5            Argentina    Argentina                      Americas       148.0
# ...                ...          ...                           ...         ...
# 179          Venezuela    Venezuela                      Americas       179.0
# 180            Vietnam      Vietnam                  Asia-Pacific       128.0
# 181              Yemen        Yemen  Middle East and North Africa         0.0
# 182             Zambia       Zambia            Sub-Saharan Africa       138.0
# 183           Zimbabwe     Zimbabwe            Sub-Saharan Africa       175.0
#
#            Region Rank  2019 Score  Property Rights  Judical Effectiveness  \
# CountryID
# 1                 39.0        51.5             19.6                   29.6
# 2                 27.0        66.5             54.8                   30.6
# 3                 14.0        46.2             31.6                   36.2
# 4                 33.0        50.6             35.9                   26.6
# 5                 26.0        52.2             47.8                   44.5
# ...                ...         ...              ...                    ...
# 179               32.0        25.9              7.6                   13.1
# 180               30.0        55.3             49.8                   40.3
# 181                0.0         0.0             19.6                   22.2
# 182               27.0        53.6             45.0                   35.6
# 183               45.0        40.4             29.7                   24.8
#
#            Government Integrity  Tax Burden  ...  GDP (Billions, PPP)  \
# CountryID                                    ...
# 1                          25.2        91.7  ...               $69.6
# 2                          40.4        86.3  ...               $36.0
# 3                          28.9        76.4  ...              $632.9
# 4                          20.5        83.9  ...              $190.3
# 5                          33.5        69.3  ...              $920.2
# ...                         ...         ...  ...                  ...
# 179                         7.9        74.7  ...              $380.7
# 180                        34.0        79.7  ...              $647.4
# 181                        20.3         0.0  ...               $38.6
# 182                        32.3        72.3  ...               $68.9
# 183                        15.8        62.3  ...               $34.0
#
#            GDP Growth Rate (%)  5 Year GDP Growth Rate (%)  \
# CountryID
# 1                          2.5                         2.9
# 2                          3.9                         2.5
# 3                          2.0                         3.1
# 4                          0.7                         2.9
# 5                          2.9                         0.7
# ...                        ...                         ...
# 179                      -14.0                        -7.8
# 180                        6.8                         6.2
# 181                      -13.8                       -16.1
# 182                        3.6                         4.0
# 183                        3.0                         2.6
#
#            GDP per Capita (PPP)  Unemployment (%)  Inflation (%)  \
# CountryID
# 1                        $1,958               8.8            5.0
# 2                       $12,507              13.9            2.0
# 3                       $15,237                10            5.6
# 4                        $6,753               8.2           31.7
# 5                       $20,876               8.7           25.7
# ...                         ...               ...            ...
# 179                     $12,114               7.7         1087.5
# 180                      $6,913               2.1            3.5
# 181                      $1,287                14            4.9
# 182                      $3,996               7.8            6.6
# 183                      $2,283                 5            1.3
#
#            FDI Inflow (Millions)  Public Debt (% of GDP)  \
# CountryID
# 1                           53.9                     7.3
# 2                       1,119.10                    71.2
# 3                       1,203.00                    25.8
# 4                      -2,254.50                    65.3
# 5                      11,857.00                    52.6
# ...                          ...                     ...
# 179                          -68                    34.9
# 180                    14,100.00                    58.2
# 181                       -269.9                   141.0
# 182                     1,091.20                    62.2
# 183                        289.4                    78.4
#
#            GDP per Capita no Dollar          2018
# CountryID
# 1                              1958   1955.006208
# 2                             12507  13364.155400
# 3                             15237  15481.787620
# 4                              6753   6452.355165
# 5                             20876  20610.568550
# ...                             ...           ...
# 179                           12114           NaN
# 180                            6913   7447.814334
# 181                            1287           NaN
# 182                            3996   4223.906936
# 183                            2283   3029.793005
#
# [186 rows x 35 columns]

# %%
result3.isna().sum()
# Out:
# Country Name                    0
# WEBNAME                         0
# Region                          0
# World Rank                      0
# Region Rank                     0
# 2019 Score                      0
# Property Rights                 0
# Judical Effectiveness           0
# Government Integrity            0
# Tax Burden                      0
# Gov't Spending                  0
# Fiscal Health                   0
# Business Freedom                0
# Labor Freedom                   0
# Monetary Freedom                0
# Trade Freedom                   0
# Investment Freedom              0
# Financial Freedom               0
# Tariff Rate (%)                 0
# Income Tax Rate (%)             0
# Corporate Tax Rate (%)          0
# Tax Burden % of GDP             0
# Gov't Expenditure % of GDP      0
# Country                         0
# Population (Millions)           0
# GDP (Billions, PPP)             0
# GDP Growth Rate (%)             0
# 5 Year GDP Growth Rate (%)      0
# GDP per Capita (PPP)            0
# Unemployment (%)                0
# Inflation (%)                   0
# FDI Inflow (Millions)           0
# Public Debt (% of GDP)          0
# GDP per Capita no Dollar        0
# 2018                           29
# dtype: int64

# %%
result4=result3.fillna(result3.mean())

# %%
result4.isna().sum()
# Out:
# Country Name                   0
# WEBNAME                        0
# Region                         0
# World Rank                     0
# Region Rank                    0
# 2019 Score                     0
# Property Rights                0
# Judical Effectiveness          0
# Government Integrity           0
# Tax Burden                     0
# Gov't Spending                 0
# Fiscal Health                  0
# Business Freedom               0
# Labor Freedom                  0
# Monetary Freedom               0
# Trade Freedom                  0
# Investment Freedom             0
# Financial Freedom              0
# Tariff Rate (%)                0
# Income Tax Rate (%)            0
# Corporate Tax Rate (%)         0
# Tax Burden % of GDP            0
# Gov't Expenditure % of GDP     0
# Country                        0
# Population (Millions)          0
# GDP (Billions, PPP)            0
# GDP Growth Rate (%)            0
# 5 Year GDP Growth Rate (%)     0
# GDP per Capita (PPP)           0
# Unemployment (%)               0
# Inflation (%)                  0
# FDI Inflow (Millions)          0
# Public Debt (% of GDP)         0
# GDP per Capita no Dollar       0
# 2018                           0
# dtype: int64

# %%
result4.head(30)
# Out:
#                      Country Name            WEBNAME  \
# CountryID
# 1                     Afghanistan        Afghanistan
# 2                         Albania            Albania
# 3                         Algeria            Algeria
# 4                          Angola             Angola
# 5                       Argentina          Argentina
# 6                         Armenia            Armenia
# 7                       Australia          Australia
# 8                         Austria            Austria
# 9                      Azerbaijan         Azerbaijan
# 10                        Bahamas            Bahamas
# 11                        Bahrain            Bahrain
# 12                     Bangladesh         Bangladesh
# 13                       Barbados           Barbados
# 14                        Belarus            Belarus
# 15                        Belgium            Belgium
# 16                         Belize             Belize
# 17                          Benin              Benin
# 18                         Bhutan             Bhutan
# 19                        Bolivia            Bolivia
# 20         Bosnia and Herzegovina  BosniaHerzegovina
# 21                       Botswana           Botswana
# 22                         Brazil             Brazil
# 186             Brunei Darussalam            Brunei
# 23                       Bulgaria           Bulgaria
# 24                   Burkina Faso        BurkinaFaso
# 25                          Burma              Burma
# 26                        Burundi            Burundi
# 27                       Cambodia           Cambodia
# 28                       Cameroon           Cameroon
# 29                         Canada             Canada
#
#                                  Region  World Rank  Region Rank  2019 Score  \
# CountryID
# 1                          Asia-Pacific       152.0         39.0        51.5
# 2                                Europe        52.0         27.0        66.5
# 3          Middle East and North Africa       171.0         14.0        46.2
# 4                    Sub-Saharan Africa       156.0         33.0        50.6
# 5                              Americas       148.0         26.0        52.2
# 6                                Europe        47.0         24.0        67.7
# 7                          Asia-Pacific         5.0          4.0        80.9
# 8                                Europe        31.0         16.0        72.0
# 9                          Asia-Pacific        60.0         13.0        65.4
# 10                             Americas        76.0         15.0        62.9
# 11         Middle East and North Africa        54.0          5.0        66.4
# 12                         Asia-Pacific       121.0         27.0        55.6
# 13                             Americas        67.0         13.0        64.7
# 14                               Europe       104.0         42.0        57.9
# 15                               Europe        48.0         25.0        67.3
# 16                             Americas       123.0         24.0        55.4
# 17                   Sub-Saharan Africa       127.0         21.0        55.3
# 18                         Asia-Pacific        74.0         16.0        62.9
# 19                             Americas       173.0         30.0        42.3
# 20                               Europe        83.0         37.0        61.9
# 21                   Sub-Saharan Africa        36.0          3.0        69.5
# 22                             Americas       150.0         27.0        51.9
# 186                        Asia-Pacific        63.0         14.0        65.1
# 23                               Europe        37.0         19.0        69.0
# 24                   Sub-Saharan Africa        96.0          9.0        59.4
# 25                         Asia-Pacific       139.0         35.0        53.6
# 26                   Sub-Saharan Africa       162.0         39.0        48.9
# 27                         Asia-Pacific       105.0         22.0        57.8
# 28                   Sub-Saharan Africa       145.0         29.0        52.4
# 29                             Americas         8.0          1.0        77.7
#
#            Property Rights  Judical Effectiveness  Government Integrity  \
# CountryID
# 1                     19.6                   29.6                  25.2
# 2                     54.8                   30.6                  40.4
# 3                     31.6                   36.2                  28.9
# 4                     35.9                   26.6                  20.5
# 5                     47.8                   44.5                  33.5
# 6                     57.2                   46.3                  38.6
# 7                     79.1                   86.5                  79.9
# 8                     84.2                   71.3                  77.4
# 9                     59.1                   53.1                  44.7
# 10                    42.2                   46.9                  43.7
# 11                    63.5                   50.7                  53.6
# 12                    36.1                   34.5                  24.4
# 13                    52.9                   59.9                  53.8
# 14                    55.2                   51.7                  37.7
# 15                    81.3                   61.6                  72.5
# 16                    41.7                   46.9                  27.2
# 17                    37.2                   32.8                  28.1
# 18                    62.5                   55.4                  54.5
# 19                    20.5                   12.3                  19.7
# 20                    40.2                   37.9                  30.2
# 21                    58.1                   45.7                  52.4
# 22                    57.3                   51.7                  28.1
# 186                   64.0                   56.0                  43.7
# 23                    62.5                   41.9                  35.1
# 24                    49.1                   42.9                  36.6
# 25                    34.7                   18.1                  30.6
# 26                    20.6                   31.0                  26.2
# 27                    37.4                   27.6                  16.7
# 28                    42.5                   31.3                  25.5
# 29                    87.0                   69.4                  84.6
#
#            Tax Burden  ...  GDP (Billions, PPP)  GDP Growth Rate (%)  \
# CountryID              ...
# 1                91.7  ...               $69.6                   2.5
# 2                86.3  ...               $36.0                   3.9
# 3                76.4  ...              $632.9                   2.0
# 4                83.9  ...              $190.3                   0.7
# 5                69.3  ...              $920.2                   2.9
# 6                84.7  ...               $28.3                   7.5
# 7                62.8  ...            $1,246.5                   2.3
# 8                50.5  ...              $439.6                   2.9
# 9                87.5  ...              $171.8                   0.1
# 10               97.3  ...               $11.6                   1.3
# 11               99.7  ...               $70.4                   3.2
# 12               72.7  ...              $687.1                   7.1
# 13               70.1  ...                $5.2                   0.9
# 14               89.4  ...              $178.9                   2.4
# 15               47.1  ...              $528.5                   1.7
# 16               79.9  ...                $3.2                   0.8
# 17               69.3  ...               $25.3                   5.6
# 18               83.0  ...                $7.0                   6.0
# 19               82.4  ...               $83.6                   4.2
# 20               84.3  ...               $44.6                   2.7
# 21               82.7  ...               $38.9                   2.2
# 22               70.5  ...            $3,240.3                   1.0
# 186              90.7  ...               $33.5                   0.5
# 23               90.2  ...              $153.1                   3.6
# 24               81.9  ...               $35.8                   6.4
# 25               86.6  ...              $328.7                   6.7
# 26               74.0  ...                $8.0                   0.0
# 27               89.7  ...               $64.3                   6.9
# 28               74.4  ...               $88.9                   3.2
# 29               76.8  ...            $1,769.3                   3.0
#
#            5 Year GDP Growth Rate (%)  GDP per Capita (PPP)  Unemployment (%)  \
# CountryID
# 1                                 2.9                $1,958               8.8
# 2                                 2.5               $12,507              13.9
# 3                                 3.1               $15,237                10
# 4                                 2.9                $6,753               8.2
# 5                                 0.7               $20,876               8.7
# 6                                 3.6                $9,456              18.2
# 7                                 2.4               $50,334               5.6
# 8                                 1.3               $49,869               5.5
# 9                                 1.2               $17,492                 5
# 10                               -0.7               $31,139              12.6
# 11                                3.8               $48,505               1.2
# 12                                6.7                $4,211               4.4
# 13                                0.6               $18,664               9.7
# 14                               -0.3               $18,931               0.5
# 15                                1.2               $46,553               7.4
# 16                                1.8                $8,324               9.3
# 17                                5.0                $2,277               2.5
# 18                                5.2                $8,744               2.4
# 19                                5.1                $7,547               3.1
# 20                                2.5               $12,724              25.6
# 21                                4.1               $17,828              17.4
# 22                               -0.5               $15,603              13.3
# 186                              -1.4               $78,196               7.1
# 23                                2.7               $21,687               6.2
# 24                                5.3                $1,889               6.3
# 25                                7.2                $6,244               0.8
# 26                                1.1                  $735               1.6
# 27                                7.1                $4,012               0.2
# 28                                4.9                $3,660               4.2
# 29                                2.1               $48,265               6.3
#
#            Inflation (%)  FDI Inflow (Millions)  Public Debt (% of GDP)  \
# CountryID
# 1                    5.0                   53.9                     7.3
# 2                    2.0               1,119.10                    71.2
# 3                    5.6               1,203.00                    25.8
# 4                   31.7              -2,254.50                    65.3
# 5                   25.7              11,857.00                    52.6
# 6                    0.9                  245.7                    53.5
# 7                    2.0              46,368.00                    41.6
# 8                    2.2               9,629.60                    78.8
# 9                   13.0               2,867.00                    54.7
# 10                   1.4                  927.7                    57.2
# 11                   1.4                  518.9                    90.3
# 12                   5.7               2,151.60                    32.4
# 13                   4.4                  286.2                   132.9
# 14                   6.0               1,276.40                    51.0
# 15                   2.2                  740.4                   103.2
# 16                   1.1                     77                    99.0
# 17                   0.1                  184.4                    54.6
# 18                   3.4                   10.3                   102.4
# 19                   2.8                  724.7                    50.9
# 20                   1.3                  425.2                    41.0
# 21                   3.3                  400.6                    15.6
# 22                   3.4              62,712.60                    84.0
# 186                 -0.1                  -46.3                     2.7
# 23                   1.2               1,070.70                    23.9
# 24                   0.4                  485.9                    38.3
# 25                   5.1               4,341.00                    34.7
# 26                  16.6                    0.3                    56.7
# 27                   2.9               2,784.40                    35.1
# 28                   0.6                  672.5                    33.8
# 29                   1.6              24,243.80                    89.7
#
#            GDP per Capita no Dollar          2018
# CountryID
# 1                              1958   1955.006208
# 2                             12507  13364.155400
# 3                             15237  15481.787620
# 4                              6753   6452.355165
# 5                             20876  20610.568550
# 6                              9456  10343.175590
# 7                             50334  51663.365090
# 8                             49869  55454.689290
# 9                             17492  18044.136780
# 10                            31139  22002.645113
# 11                            48505  47303.048510
# 12                             4211   4371.754986
# 13                            18664  18554.129280
# 14                            18931  19994.804080
# 15                            46553  51407.998340
# 16                             8324   8648.088800
# 17                             2277   2424.755845
# 18                             8744  10167.934060
# 19                             7547   7873.166243
# 20                            12724  14623.674050
# 21                            17828  18615.793340
# 22                            15603  16096.400960
# 186                           78196  80920.048680
# 23                            21687  21960.369940
# 24                             1889   1984.884306
# 25                             6244  22002.645113
# 26                              735    744.182072
# 27                             4012   4360.854404
# 28                             3660   3785.079978
# 29                            48265  48130.255970
#
# [30 rows x 35 columns]

# %%
result5=result4.merge(df_SQL, how='left',left_on='Country Name', right_on='ï»¿Name')

# %%
result5.head()
# Out:
#   Country Name      WEBNAME                        Region  World Rank  \
# 0  Afghanistan  Afghanistan                  Asia-Pacific       152.0
# 1      Albania      Albania                        Europe        52.0
# 2      Algeria      Algeria  Middle East and North Africa       171.0
# 3       Angola       Angola            Sub-Saharan Africa       156.0
# 4    Argentina    Argentina                      Americas       148.0
#
#    Region Rank  2019 Score  Property Rights  Judical Effectiveness  \
# 0         39.0        51.5             19.6                   29.6
# 1         27.0        66.5             54.8                   30.6
# 2         14.0        46.2             31.6                   36.2
# 3         33.0        50.6             35.9                   26.6
# 4         26.0        52.2             47.8                   44.5
#
#    Government Integrity  Tax Burden  ...  5 Year GDP Growth Rate (%)  \
# 0                  25.2        91.7  ...                         2.9
# 1                  40.4        86.3  ...                         2.5
# 2                  28.9        76.4  ...                         3.1
# 3                  20.5        83.9  ...                         2.9
# 4                  33.5        69.3  ...                         0.7
#
#    GDP per Capita (PPP)  Unemployment (%)  Inflation (%)  \
# 0                $1,958               8.8            5.0
# 1               $12,507              13.9            2.0
# 2               $15,237                10            5.6
# 3                $6,753               8.2           31.7
# 4               $20,876               8.7           25.7
#
#    FDI Inflow (Millions)  Public Debt (% of GDP)  GDP per Capita no Dollar  \
# 0                   53.9                     7.3                      1958
# 1               1,119.10                    71.2                     12507
# 2               1,203.00                    25.8                     15237
# 3              -2,254.50                    65.3                      6753
# 4              11,857.00                    52.6                     20876
#
#            2018      ï»¿Name  Deaths - cumulative total per 100000 population
# 0   1955.006208  Afghanistan                                             20.0
# 1  13364.155400      Albania                                            121.0
# 2  15481.787620      Algeria                                             16.0
# 3   6452.355165       Angola                                              6.0
# 4  20610.568550    Argentina                                            283.0
#
# [5 rows x 37 columns]

# %%
result5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 186 entries, 0 to 185
# Data columns (total 37 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Country Name                                     186 non-null    object
#  1   WEBNAME                                          186 non-null    object
#  2   Region                                           186 non-null    object
#  3   World Rank                                       186 non-null    float64
#  4   Region Rank                                      186 non-null    float64
#  5   2019 Score                                       186 non-null    float64
#  6   Property Rights                                  186 non-null    float64
#  7   Judical Effectiveness                            186 non-null    float64
#  8   Government Integrity                             186 non-null    float64
#  9   Tax Burden                                       186 non-null    float64
#  10  Gov't Spending                                   186 non-null    float64
#  11  Fiscal Health                                    186 non-null    float64
#  12  Business Freedom                                 186 non-null    float64
#  13  Labor Freedom                                    186 non-null    float64
#  14  Monetary Freedom                                 186 non-null    float64
#  15  Trade Freedom                                    186 non-null    float64
#  16  Investment Freedom                               186 non-null    float64
#  17  Financial Freedom                                186 non-null    float64
#  18  Tariff Rate (%)                                  186 non-null    float64
#  19  Income Tax Rate (%)                              186 non-null    float64
#  20  Corporate Tax Rate (%)                           186 non-null    float64
#  21  Tax Burden % of GDP                              186 non-null    float64
#  22  Gov't Expenditure % of GDP                       186 non-null    float64
#  23  Country                                          186 non-null    object
#  24  Population (Millions)                            186 non-null    object
#  25  GDP (Billions, PPP)                              186 non-null    object
#  26  GDP Growth Rate (%)                              186 non-null    float64
#  27  5 Year GDP Growth Rate (%)                       186 non-null    float64
#  28  GDP per Capita (PPP)                             186 non-null    object
#  29  Unemployment (%)                                 186 non-null    object
#  30  Inflation (%)                                    186 non-null    float64
#  31  FDI Inflow (Millions)                            186 non-null    object
#  32  Public Debt (% of GDP)                           186 non-null    float64
#  33  GDP per Capita no Dollar                         186 non-null    object
#  34  2018                                             186 non-null    float64
#  35  ï»¿Name                                          160 non-null    object
#  36  Deaths - cumulative total per 100000 population  160 non-null    float64
# dtypes: float64(26), object(11)
# memory usage: 55.2+ KB

# %%
result_group5=result5.groupby(['Region'])["2018"].agg(['mean','median'])

# %%
result_group5
# Out:
#                                       mean        median
# Region
# Americas                      18220.427308  16883.748155
# Asia-Pacific                  18539.016512  13473.663090
# Europe                        36668.100917  33415.437900
# Middle East and North Africa  35814.222561  22002.645113
# Sub-Saharan Africa             8698.751246   3783.809296

# %%
for x in result5:
    print(x)
# Out:
# Country Name
# WEBNAME
# Region
# World Rank
# Region Rank
# 2019 Score
# Property Rights
# Judical Effectiveness
# Government Integrity
# Tax Burden
# Gov't Spending
# Fiscal Health
# Business Freedom
# Labor Freedom
# Monetary Freedom
# Trade Freedom
# Investment Freedom
# Financial Freedom
# Tariff Rate (%)
# Income Tax Rate (%)
# Corporate Tax Rate (%)
# Tax Burden % of GDP
# Gov't Expenditure % of GDP
# Country
# Population (Millions)
# GDP (Billions, PPP)
# GDP Growth Rate (%)
# 5 Year GDP Growth Rate (%)
# GDP per Capita (PPP)
# Unemployment (%)
# Inflation (%)
# FDI Inflow (Millions)
# Public Debt (% of GDP)
# GDP per Capita no Dollar
# 2018
# ï»¿Name
# Deaths - cumulative total per 100000 population

# %%
for index, row in result3.head(2).iterrows():
    print(index)
    print(row)
# Out:
# 1
# Country Name                    Afghanistan
# WEBNAME                         Afghanistan
# Region                         Asia-Pacific
# World Rank                            152.0
# Region Rank                            39.0
# 2019 Score                             51.5
# Property Rights                        19.6
# Judical Effectiveness                  29.6
# Government Integrity                   25.2
# Tax Burden                             91.7
# Gov't Spending                         80.3
# Fiscal Health                          99.3
# Business Freedom                       49.2
# Labor Freedom                          60.4
# Monetary Freedom                       76.7
# Trade Freedom                          66.0
# Investment Freedom                     10.0
# Financial Freedom                      10.0
# Tariff Rate (%)                         7.0
# Income Tax Rate (%)                    20.0
# Corporate Tax Rate (%)                 20.0
# Tax Burden % of GDP                     5.0
# Gov't Expenditure % of GDP             25.6
# Country                         Afghanistan
# Population (Millions)                  35.5
# GDP (Billions, PPP)                  $69.6
# GDP Growth Rate (%)                     2.5
# 5 Year GDP Growth Rate (%)              2.9
# GDP per Capita (PPP)                 $1,958
# Unemployment (%)                        8.8
# Inflation (%)                           5.0
# FDI Inflow (Millions)                  53.9
# Public Debt (% of GDP)                  7.3
# GDP per Capita no Dollar               1958
# 2018                            1955.006208
# Name: 1, dtype: object
# 2
# Country Name                      Albania
# WEBNAME                           Albania
# Region                             Europe
# World Rank                           52.0
# Region Rank                          27.0
# 2019 Score                           66.5
# Property Rights                      54.8
# Judical Effectiveness                30.6
# Government Integrity                 40.4
# Tax Burden                           86.3
# Gov't Spending                       73.9
# Fiscal Health                        80.6
# Business Freedom                     69.3
# Labor Freedom                        52.7
# Monetary Freedom                     81.5
# Trade Freedom                        87.8
# Investment Freedom                   70.0
# Financial Freedom                    70.0
# Tariff Rate (%)                       1.1
# Income Tax Rate (%)                  23.0
# Corporate Tax Rate (%)               15.0
# Tax Burden % of GDP                  24.9
# Gov't Expenditure % of GDP           29.5
# Country                           Albania
# Population (Millions)                 2.9
# GDP (Billions, PPP)                $36.0
# GDP Growth Rate (%)                   3.9
# 5 Year GDP Growth Rate (%)            2.5
# GDP per Capita (PPP)              $12,507
# Unemployment (%)                     13.9
# Inflation (%)                         2.0
# FDI Inflow (Millions)            1,119.10
# Public Debt (% of GDP)               71.2
# GDP per Capita no Dollar            12507
# 2018                           13364.1554
# Name: 2, dtype: object

# %%
for index, row in result5.head().iterrows():
    print(f"{row[1]} has a property rights scorce of {row[6]} which partly explains its GDP of {row[25]} billion")
# Out:
# Afghanistan has a property rights scorce of 19.6 which partly explains its GDP of $69.6  billion
# Albania has a property rights scorce of 54.8 which partly explains its GDP of $36.0  billion
# Algeria has a property rights scorce of 31.6 which partly explains its GDP of $632.9  billion
# Angola has a property rights scorce of 35.9 which partly explains its GDP of $190.3  billion
# Argentina has a property rights scorce of 47.8 which partly explains its GDP of $920.2  billion

# %%
def region_west(result5):
    if result5 in ['Europe','Americas']:
        return 'West'
    else:
        return "Not West"

# %%
result5['west'] = result5['Region'].apply(region_west)
result5.tail()
# Out:
#     Country Name    WEBNAME                        Region  World Rank  \
# 181    Venezuela  Venezuela                      Americas       179.0
# 182      Vietnam    Vietnam                  Asia-Pacific       128.0
# 183        Yemen      Yemen  Middle East and North Africa         0.0
# 184       Zambia     Zambia            Sub-Saharan Africa       138.0
# 185     Zimbabwe   Zimbabwe            Sub-Saharan Africa       175.0
#
#      Region Rank  2019 Score  Property Rights  Judical Effectiveness  \
# 181         32.0        25.9              7.6                   13.1
# 182         30.0        55.3             49.8                   40.3
# 183          0.0         0.0             19.6                   22.2
# 184         27.0        53.6             45.0                   35.6
# 185         45.0        40.4             29.7                   24.8
#
#      Government Integrity  Tax Burden  ...  GDP per Capita (PPP)  \
# 181                   7.9        74.7  ...               $12,114
# 182                  34.0        79.7  ...                $6,913
# 183                  20.3         0.0  ...                $1,287
# 184                  32.3        72.3  ...                $3,996
# 185                  15.8        62.3  ...                $2,283
#
#      Unemployment (%)  Inflation (%)  FDI Inflow (Millions)  \
# 181               7.7         1087.5                    -68
# 182               2.1            3.5              14,100.00
# 183                14            4.9                 -269.9
# 184               7.8            6.6               1,091.20
# 185                 5            1.3                  289.4
#
#      Public Debt (% of GDP)  GDP per Capita no Dollar          2018   ï»¿Name  \
# 181                    34.9                     12114  22002.645113       NaN
# 182                    58.2                      6913   7447.814334       NaN
# 183                   141.0                      1287  22002.645113     Yemen
# 184                    62.2                      3996   4223.906936    Zambia
# 185                    78.4                      2283   3029.793005  Zimbabwe
#
#      Deaths - cumulative total per 100000 population      west
# 181                                              NaN      West
# 182                                              NaN  Not West
# 183                                              7.0  Not West
# 184                                             22.0  Not West
# 185                                             37.0  Not West
#
# [5 rows x 38 columns]

# %%
result5['Ability to service National Debt']=result5['Tax Burden % of GDP']/result5['Public Debt (% of GDP)']

# %%
result5['Ability to service National Debt']
# Out:
# 0      0.684932
# 1      0.349719
# 2      0.949612
# 3      0.315467
# 4      0.585551
#          ...
# 181    0.426934
# 182    0.309278
# 183    0.000000
# 184    0.287781
# 185    0.284439
# Name: Ability to service National Debt, Length: 186, dtype: float64

# %%
# This shows a nations ability to pay its national debt

# %%
result5[result5['Ability to service National Debt']>1]
# Out:
#           Country Name         WEBNAME              Region  World Rank  \
# 20            Botswana        Botswana  Sub-Saharan Africa        36.0
# 22   Brunei Darussalam         Brunei         Asia-Pacific        63.0
# 23            Bulgaria        Bulgaria              Europe        37.0
# 45             Denmark         Denmark              Europe        14.0
# 54             Estonia         Estonia              Europe        15.0
# 72           Hong Kong        HongKong        Asia-Pacific         1.0
# 90              Kosovo          Kosovo              Europe        51.0
# 96             Lesotho         Lesotho  Sub-Saharan Africa       142.0
# 101         Luxembourg      Luxembourg              Europe        17.0
# 102              Macau           Macau        Asia-Pacific        34.0
# 122        New Zealand      NewZealand        Asia-Pacific         3.0
# 126             Norway          Norway              Europe        26.0
# 138             Russia          Russia              Europe        98.0
# 152    Solomon Islands  SolomonIslands        Asia-Pacific       133.0
# 159             Sweden          Sweden              Europe        19.0
# 166        Timor-Leste      TimorLeste        Asia-Pacific       172.0
#
#      Region Rank  2019 Score  Property Rights  Judical Effectiveness  \
# 20           3.0        69.5             58.1                   45.7
# 22          14.0        65.1             64.0                   56.0
# 23          19.0        69.0             62.5                   41.9
# 45           6.0        76.7             86.2                   77.8
# 54           7.0        76.6             81.5                   76.0
# 72           1.0        90.2             93.3                   75.3
# 90          26.0        67.0             57.2                   53.5
# 96          28.0        53.1             41.5                   45.7
# 101          9.0        75.9             83.0                   72.4
# 102          9.0        71.0             60.0                   60.0
# 122          3.0        84.4             95.0                   83.5
# 126         15.0        73.0             86.1                   81.2
# 138         41.0        58.9             52.4                   45.1
# 152         33.0        54.6             49.9                   51.7
# 159         10.0        75.2             89.5                   84.0
# 166         42.0        44.2             29.7                   13.1
#
#      Government Integrity  Tax Burden  ...  Unemployment (%)  Inflation (%)  \
# 20                   52.4        82.7  ...              17.4            3.3
# 22                   43.7        90.7  ...               7.1           -0.1
# 23                   35.1        90.2  ...               6.2            1.2
# 45                   85.8        42.0  ...               5.7            1.1
# 54                   73.1        79.9  ...               5.8            3.7
# 72                   83.8        93.1  ...               3.1            1.5
# 90                   44.7        92.5  ...                 0            1.5
# 96                   30.9        59.4  ...              27.3            5.6
# 101                  85.8        65.4  ...               5.5            2.1
# 102                  33.2        77.1  ...                 2            1.2
# 122                  96.7        71.0  ...               4.9            1.9
# 126                  92.3        57.4  ...               4.2            1.9
# 138                  36.6        89.4  ...               5.2            3.7
# 152                  33.5        65.5  ...               2.1           -0.4
# 159                  88.0        43.2  ...               6.7            1.9
# 166                  32.1        96.3  ...               3.4            0.6
#
#      FDI Inflow (Millions)  Public Debt (% of GDP)  GDP per Capita no Dollar  \
# 20                   400.6                    15.6                     17828
# 22                   -46.3                     2.7                     78196
# 23                1,070.70                    23.9                     21687
# 45               -3,114.70                    36.4                     49883
# 54                   784.4                     8.8                     31750
# 72              104,333.00                     0.1                     61393
# 90                     3.6                    20.9                     10515
# 96                     135                    34.7                      3581
# 101               6,622.70                    23.0                    106374
# 102               1,996.80                     0.0                    111629
# 122               3,572.00                    26.4                     38934
# 126              -8,296.90                    36.7                     71831
# 138              25,284.00                    17.4                     27834
# 152                   36.5                    10.0                      2157
# 159              15,395.70                    40.9                     51475
# 166                    6.7                     0.0                      5444
#
#               2018            ï»¿Name  \
# 20    18615.793340           Botswana
# 22    80920.048680  Brunei Darussalam
# 23    21960.369940           Bulgaria
# 45    55671.165270            Denmark
# 54    35973.776460            Estonia
# 72    22002.645113                NaN
# 90    11348.363450                NaN
# 96     3219.457157            Lesotho
# 101  113337.420500         Luxembourg
# 102   22002.645113                NaN
# 122   41005.420870        New Zealand
# 126   65510.585270             Norway
# 138   22002.645113                NaN
# 152    2422.819533    Solomon Islands
# 159   53208.884360             Sweden
# 166    7658.434996        Timor-Leste
#
#      Deaths - cumulative total per 100000 population      west  \
# 20                                             111.0  Not West
# 22                                              35.0  Not West
# 23                                             527.0      West
# 45                                              99.0      West
# 54                                             186.0      West
# 72                                               NaN  Not West
# 90                                               NaN      West
# 96                                              33.0  Not West
# 101                                            166.0      West
# 102                                              NaN  Not West
# 122                                              8.0  Not West
# 126                                             47.0      West
# 138                                              NaN      West
# 152                                             19.0  Not West
# 159                                            178.0      West
# 166                                             10.0  Not West
#
#      Ability to service National Debt
# 20                           1.596154
# 22                           8.962963
# 23                           1.171548
# 45                           1.260989
# 54                           3.943182
# 72                         140.000000
# 90                           1.124402
# 96                           1.354467
# 101                          1.613043
# 102                               inf
# 122                          1.215909
# 126                          1.035422
# 138                          1.275862
# 152                          3.080000
# 159                          1.078240
# 166                               inf
#
# [16 rows x 39 columns]

# %%
result5.isna().sum()
# Out:
# Country Name                                        0
# WEBNAME                                             0
# Region                                              0
# World Rank                                          0
# Region Rank                                         0
# 2019 Score                                          0
# Property Rights                                     0
# Judical Effectiveness                               0
# Government Integrity                                0
# Tax Burden                                          0
# Gov't Spending                                      0
# Fiscal Health                                       0
# Business Freedom                                    0
# Labor Freedom                                       0
# Monetary Freedom                                    0
# Trade Freedom                                       0
# Investment Freedom                                  0
# Financial Freedom                                   0
# Tariff Rate (%)                                     0
# Income Tax Rate (%)                                 0
# Corporate Tax Rate (%)                              0
# Tax Burden % of GDP                                 0
# Gov't Expenditure % of GDP                          0
# Country                                             0
# Population (Millions)                               0
# GDP (Billions, PPP)                                 0
# GDP Growth Rate (%)                                 0
# 5 Year GDP Growth Rate (%)                          0
# GDP per Capita (PPP)                                0
# Unemployment (%)                                    0
# Inflation (%)                                       0
# FDI Inflow (Millions)                               0
# Public Debt (% of GDP)                              0
# GDP per Capita no Dollar                            0
# 2018                                                0
# ï»¿Name                                            26
# Deaths - cumulative total per 100000 population    26
# west                                                0
# Ability to service National Debt                    4
# dtype: int64

# %%
result6=result5.fillna(result5.mean())

# %% [raw]
# result6

# %%
result6.isna().sum()
# Out:
# Country Name                                        0
# WEBNAME                                             0
# Region                                              0
# World Rank                                          0
# Region Rank                                         0
# 2019 Score                                          0
# Property Rights                                     0
# Judical Effectiveness                               0
# Government Integrity                                0
# Tax Burden                                          0
# Gov't Spending                                      0
# Fiscal Health                                       0
# Business Freedom                                    0
# Labor Freedom                                       0
# Monetary Freedom                                    0
# Trade Freedom                                       0
# Investment Freedom                                  0
# Financial Freedom                                   0
# Tariff Rate (%)                                     0
# Income Tax Rate (%)                                 0
# Corporate Tax Rate (%)                              0
# Tax Burden % of GDP                                 0
# Gov't Expenditure % of GDP                          0
# Country                                             0
# Population (Millions)                               0
# GDP (Billions, PPP)                                 0
# GDP Growth Rate (%)                                 0
# 5 Year GDP Growth Rate (%)                          0
# GDP per Capita (PPP)                                0
# Unemployment (%)                                    0
# Inflation (%)                                       0
# FDI Inflow (Millions)                               0
# Public Debt (% of GDP)                              0
# GDP per Capita no Dollar                            0
# 2018                                                0
# ï»¿Name                                            26
# Deaths - cumulative total per 100000 population     0
# west                                                0
# Ability to service National Debt                    0
# dtype: int64

# %%
result6 = result6.drop("ï»¿Name", axis=1)

# %%
result6.iloc[[1,10,100], [0,1,2,3,8]]
# Out:
#     Country Name    WEBNAME                        Region  World Rank  \
# 1        Albania    Albania                        Europe        52.0
# 10       Bahrain    Bahrain  Middle East and North Africa        54.0
# 100    Lithuania  Lithuania                        Europe        21.0
#
#      Government Integrity
# 1                    40.4
# 10                   53.6
# 100                  47.8

# %%
dfregion
# Out:
#                               World Rank  Region Rank  2019 Score  \
# Region
# Americas                       90.156250         16.5   59.600000
# Asia-Pacific                   92.767442         22.0   60.634884
# Europe                         48.863636         22.5   68.627273
# Middle East and North Africa   90.285714          7.5   61.257143
# Sub-Saharan Africa            127.702128         24.0   54.182979
#
#                               Property Rights  Judical Effectiveness  \
# Region
# Americas                            48.265625              40.212500
# Asia-Pacific                        54.044186              46.116279
# Europe                              70.031818              56.590909
# Middle East and North Africa        47.966667              44.827778
# Sub-Saharan Africa                  38.904167              36.243750
#
#                               Government Integrity  Tax Burden  \
# Region
# Americas                                 38.028125   77.156250
# Asia-Pacific                             41.888372   81.186047
# Europe                                   55.811364   72.102273
# Middle East and North Africa             40.594444   87.721429
# Sub-Saharan Africa                       30.572917   75.270213
#
#                               Gov't Spending  Fiscal Health  Business Freedom  \
# Region
# Americas                           70.109375      64.709375         62.368750
# Asia-Pacific                       67.209302      70.572093         66.146512
# Europe                             46.718182      85.063636         74.797727
# Middle East and North Africa       58.070588      41.964706         63.027778
# Sub-Saharan Africa                 76.021277      53.529787         51.758333
#
#                               ...  Financial Freedom  Tariff Rate (%)  \
# Region                        ...
# Americas                      ...          49.062500         6.281250
# Asia-Pacific                  ...          42.558140         6.195349
# Europe                        ...          62.888889         2.309091
# Middle East and North Africa  ...          52.857143         5.806250
# Sub-Saharan Africa            ...          39.574468         9.100000
#
#                               Income Tax Rate (%)  Corporate Tax Rate (%)  \
# Region
# Americas                                29.290625               26.937500
# Asia-Pacific                            24.307143               22.745238
# Europe                                  30.484444               19.184444
# Middle East and North Africa            17.617647               16.558824
# Sub-Saharan Africa                      32.510638               30.000000
#
#                               Tax Burden % of GDP  \
# Region
# Americas                                22.790625
# Asia-Pacific                            17.111905
# Europe                                  33.781818
# Middle East and North Africa            13.371429
# Sub-Saharan Africa                      17.970213
#
#                               Gov't Expenditure % of GDP   \
# Region
# Americas                                        30.453125
# Asia-Pacific                                    33.230233
# Europe                                          41.427273
# Middle East and North Africa                    41.993750
# Sub-Saharan Africa                              26.917021
#
#                               GDP Growth Rate (%)  5 Year GDP Growth Rate (%)  \
# Region
# Americas                                 1.587500                    2.006250
# Asia-Pacific                             4.332558                    4.180952
# Europe                                   3.468182                    2.472727
# Middle East and North Africa             4.817647                    1.123529
# Sub-Saharan Africa                       3.477083                    3.716667
#
#                               Inflation (%)  Public Debt (% of GDP)
# Region
# Americas                          38.368750               58.481250
# Asia-Pacific                       3.595238               46.707143
# Europe                             2.579545               59.950000
# Middle East and North Africa       5.417647               62.629412
# Sub-Saharan Africa                 7.282979               58.336170
#
# [5 rows x 24 columns]

# %%
result6.isna().sum()# aleady done just above
# Out:
# Country Name                                       0
# WEBNAME                                            0
# Region                                             0
# World Rank                                         0
# Region Rank                                        0
# 2019 Score                                         0
# Property Rights                                    0
# Judical Effectiveness                              0
# Government Integrity                               0
# Tax Burden                                         0
# Gov't Spending                                     0
# Fiscal Health                                      0
# Business Freedom                                   0
# Labor Freedom                                      0
# Monetary Freedom                                   0
# Trade Freedom                                      0
# Investment Freedom                                 0
# Financial Freedom                                  0
# Tariff Rate (%)                                    0
# Income Tax Rate (%)                                0
# Corporate Tax Rate (%)                             0
# Tax Burden % of GDP                                0
# Gov't Expenditure % of GDP                         0
# Country                                            0
# Population (Millions)                              0
# GDP (Billions, PPP)                                0
# GDP Growth Rate (%)                                0
# 5 Year GDP Growth Rate (%)                         0
# GDP per Capita (PPP)                               0
# Unemployment (%)                                   0
# Inflation (%)                                      0
# FDI Inflow (Millions)                              0
# Public Debt (% of GDP)                             0
# GDP per Capita no Dollar                           0
# 2018                                               0
# Deaths - cumulative total per 100000 population    0
# west                                               0
# Ability to service National Debt                   0
# dtype: int64

# %%
#seaborn in datacamp for scatter plot. Chapter 1/chapter 2 videos. CHapter2 - customizing scatter plots
import matplotlib.patches as mpatches

# %%
g=sns.relplot(y='2018',x='2019 Score', data=result6, kind='scatter', size='Population (Millions)', hue='Region', sizes=(15,100), legend= False)
red_patch = mpatches.Patch(color='firebrick', label='Sub-Saharan Africa')
blue_patch = mpatches.Patch(color='blue', label='Asia-Pacific')
gold_patch = mpatches.Patch(color='chocolate', label='Europe')
green_patch = mpatches.Patch(color='green', label='Middle East and North Africa')
purple_patch = mpatches.Patch(color='purple', label='Americas')
plt.legend(handles=[red_patch, blue_patch, gold_patch, green_patch, purple_patch])
g.set_axis_labels("2019 Score", "2018 GDP")

# %%
# maybe I should rename 2018 to 2018 gdp

# %%
result6.dtypes
# Out:
# Country Name                                        object
# WEBNAME                                             object
# Region                                              object
# World Rank                                         float64
# Region Rank                                        float64
# 2019 Score                                         float64
# Property Rights                                    float64
# Judical Effectiveness                              float64
# Government Integrity                               float64
# Tax Burden                                         float64
# Gov't Spending                                     float64
# Fiscal Health                                      float64
# Business Freedom                                   float64
# Labor Freedom                                      float64
# Monetary Freedom                                   float64
# Trade Freedom                                      float64
# Investment Freedom                                 float64
# Financial Freedom                                  float64
# Tariff Rate (%)                                    float64
# Income Tax Rate (%)                                float64
# Corporate Tax Rate (%)                             float64
# Tax Burden % of GDP                                float64
# Gov't Expenditure % of GDP                         float64
# Country                                             object
# Population (Millions)                               object
# GDP (Billions, PPP)                                 object
# GDP Growth Rate (%)                                float64
# 5 Year GDP Growth Rate (%)                         float64
# GDP per Capita (PPP)                                object
# Unemployment (%)                                    object
# Inflation (%)                                      float64
# FDI Inflow (Millions)                               object
# Public Debt (% of GDP)                             float64
# GDP per Capita no Dollar                            object
# 2018                                               float64
# Deaths - cumulative total per 100000 population    float64
# west                                                object
# Ability to service National Debt                   float64
# dtype: object

# %%
sns.relplot(y='5 Year GDP Growth Rate (%)', x='2019 Score', data=result6, kind='line')

# %%
plt.subplots(figsize=(10,5))  #This increases size
plt.scatter(df['Region'], df['2019 Score'], s=5)
plt.show()

# %%
plt.scatter(x=result6['Monetary Freedom'], y=result6['Inflation (%)'])

# %%
result7= result6['Inflation (%)'].nlargest(5)

# %%
result7
# Out:
# 181    1087.5
# 37       41.5
# 157      32.4
# 3        31.7
# 98       28.0
# Name: Inflation (%), dtype: float64

# %%
result8=result6.drop(labels=181, axis=0)

# %%
result7
# Out:
# 181    1087.5
# 37       41.5
# 157      32.4
# 3        31.7
# 98       28.0
# Name: Inflation (%), dtype: float64

# %%
plt.scatter(x=result8['Monetary Freedom'], y=result8['Inflation (%)'])
plt.title('Monetary Freedom vs Inflation')
# Out:
# Text(0.5, 1.0, 'Monetary Freedom vs Inflation')

# %%
result7.dtypes
# Out:
# dtype('float64')

# %%
dfregion
# Out:
#                               World Rank  Region Rank  2019 Score  \
# Region
# Americas                       90.156250         16.5   59.600000
# Asia-Pacific                   92.767442         22.0   60.634884
# Europe                         48.863636         22.5   68.627273
# Middle East and North Africa   90.285714          7.5   61.257143
# Sub-Saharan Africa            127.702128         24.0   54.182979
#
#                               Property Rights  Judical Effectiveness  \
# Region
# Americas                            48.265625              40.212500
# Asia-Pacific                        54.044186              46.116279
# Europe                              70.031818              56.590909
# Middle East and North Africa        47.966667              44.827778
# Sub-Saharan Africa                  38.904167              36.243750
#
#                               Government Integrity  Tax Burden  \
# Region
# Americas                                 38.028125   77.156250
# Asia-Pacific                             41.888372   81.186047
# Europe                                   55.811364   72.102273
# Middle East and North Africa             40.594444   87.721429
# Sub-Saharan Africa                       30.572917   75.270213
#
#                               Gov't Spending  Fiscal Health  Business Freedom  \
# Region
# Americas                           70.109375      64.709375         62.368750
# Asia-Pacific                       67.209302      70.572093         66.146512
# Europe                             46.718182      85.063636         74.797727
# Middle East and North Africa       58.070588      41.964706         63.027778
# Sub-Saharan Africa                 76.021277      53.529787         51.758333
#
#                               ...  Financial Freedom  Tariff Rate (%)  \
# Region                        ...
# Americas                      ...          49.062500         6.281250
# Asia-Pacific                  ...          42.558140         6.195349
# Europe                        ...          62.888889         2.309091
# Middle East and North Africa  ...          52.857143         5.806250
# Sub-Saharan Africa            ...          39.574468         9.100000
#
#                               Income Tax Rate (%)  Corporate Tax Rate (%)  \
# Region
# Americas                                29.290625               26.937500
# Asia-Pacific                            24.307143               22.745238
# Europe                                  30.484444               19.184444
# Middle East and North Africa            17.617647               16.558824
# Sub-Saharan Africa                      32.510638               30.000000
#
#                               Tax Burden % of GDP  \
# Region
# Americas                                22.790625
# Asia-Pacific                            17.111905
# Europe                                  33.781818
# Middle East and North Africa            13.371429
# Sub-Saharan Africa                      17.970213
#
#                               Gov't Expenditure % of GDP   \
# Region
# Americas                                        30.453125
# Asia-Pacific                                    33.230233
# Europe                                          41.427273
# Middle East and North Africa                    41.993750
# Sub-Saharan Africa                              26.917021
#
#                               GDP Growth Rate (%)  5 Year GDP Growth Rate (%)  \
# Region
# Americas                                 1.587500                    2.006250
# Asia-Pacific                             4.332558                    4.180952
# Europe                                   3.468182                    2.472727
# Middle East and North Africa             4.817647                    1.123529
# Sub-Saharan Africa                       3.477083                    3.716667
#
#                               Inflation (%)  Public Debt (% of GDP)
# Region
# Americas                          38.368750               58.481250
# Asia-Pacific                       3.595238               46.707143
# Europe                             2.579545               59.950000
# Middle East and North Africa       5.417647               62.629412
# Sub-Saharan Africa                 7.282979               58.336170
#
# [5 rows x 24 columns]

# %%
# Visulation of mean of "Econmic Freedom" by Region

# %%
result6.groupby('Region').mean()['2019 Score'].plot.bar()
# Out:
# <AxesSubplot:xlabel='Region'>

# %%
result6.groupby('Region').mean()['2018'].plot.bar()
# Out:
# <AxesSubplot:xlabel='Region'>

# %%
result6.groupby('Region').mean()['Deaths - cumulative total per 100000 population'].plot.bar()
# Out:
# <AxesSubplot:xlabel='Region'>

# %%
result6.groupby('Region').mean()['5 Year GDP Growth Rate (%)'].plot.bar()
# Out:
# <AxesSubplot:xlabel='Region'>

# %%
plt.hist(result6['2019 Score'], bins=20)
# Out:
# (array([ 6.,  1.,  0.,  0.,  0.,  1.,  1.,  0.,  3.,  3., 11., 27., 34.,
#         27., 25., 18., 15., 10.,  2.,  2.]),
#  array([ 0.  ,  4.51,  9.02, 13.53, 18.04, 22.55, 27.06, 31.57, 36.08,
#         40.59, 45.1 , 49.61, 54.12, 58.63, 63.14, 67.65, 72.16, 76.67,
#         81.18, 85.69, 90.2 ]),
#  <BarContainer object of 20 artists>)

# %%
# Shows the distribution of scores

# %%
# Shows relationship between Covid deaths per 100,000 vs 2019 Score

# %%
plt.subplots(figsize=(10,5))  #This increases size
plt.scatter(y=result6['Deaths - cumulative total per 100000 population'], x=result6['2019 Score'], s=5)
plt.show()

# %%
# Corporation tax vs gdp growth...like ireland

# %%
sns.jointplot(data=result6, x='Corporate Tax Rate (%)',  y='5 Year GDP Growth Rate (%)', kind='reg')

# %%
# No relationship between Corporation Tax and 5 Year GDP Growth Rate (%)

# %%
result9=result8.loc[:,['Gov\'t Spending', 'Inflation (%)', '2018', 'Deaths - cumulative total per 100000 population']]

# %%
sns.pairplot(result9)

# %%
from matplotlib.patches import Polygon

# %%
boxplot = result6.boxplot(column=['Inflation (%)', 'Corporate Tax Rate (%)', '2018'])

# %%
boxplot2 = result6.boxplot(column=['Inflation (%)'])

# %%
boxplot3 = result8.boxplot(column=['Inflation (%)'])

# %%
boxplot4 = result8.boxplot(column=['2018'])

# %%
result10=result6[result6['Inflation (%)'] > 15]

# %%
result10
# Out:
#                                 Country Name                  WEBNAME  \
# 3                                     Angola                   Angola
# 4                                  Argentina                Argentina
# 26                                   Burundi                  Burundi
# 37   Congo, Democratic Republic of the Congo  DemcoraticRepublicCongo
# 50                                     Egypt                    Egypt
# 98                                     Libya                    Libya
# 118                               Mozambique               Mozambique
# 125                                  Nigeria                  Nigeria
# 148                             Sierra Leone              SierraLeone
# 157                                    Sudan                    Sudan
# 158                                 Suriname                 Suriname
# 181                                Venezuela                Venezuela
#
#                            Region  World Rank  Region Rank  2019 Score  \
# 3              Sub-Saharan Africa       156.0         33.0        50.6
# 4                        Americas       148.0         26.0        52.2
# 26             Sub-Saharan Africa       162.0         39.0        48.9
# 37             Sub-Saharan Africa       157.0         34.0        50.3
# 50   Middle East and North Africa       144.0         11.0        52.5
# 98   Middle East and North Africa         0.0          0.0         0.0
# 118            Sub-Saharan Africa       163.0         40.0        48.6
# 125            Sub-Saharan Africa       111.0         14.0        57.3
# 148            Sub-Saharan Africa       167.0         42.0        47.5
# 157            Sub-Saharan Africa       166.0         41.0        47.7
# 158                      Americas       165.0         28.0        48.1
# 181                      Americas       179.0         32.0        25.9
#
#      Property Rights  Judical Effectiveness  Government Integrity  Tax Burden  \
# 3               35.9                   26.6                  20.5        83.9
# 4               47.8                   44.5                  33.5        69.3
# 26              20.6                   31.0                  26.2        74.0
# 37              25.3                   30.7                  26.2        73.8
# 50              37.0                   48.3                  29.2        85.2
# 98               7.6                   24.4                  15.8         0.0
# 118             33.9                   35.2                  28.1        75.5
# 125             36.5                   34.3                  20.5        85.0
# 148             35.5                   34.5                  26.2        87.3
# 157             27.5                   22.2                  26.2        86.3
# 158             49.1                   22.2                  35.5        70.9
# 181              7.6                   13.1                   7.9        74.7
#
#      ...  GDP per Capita (PPP)  Unemployment (%)  Inflation (%)  \
# 3    ...                $6,753               8.2           31.7
# 4    ...               $20,876               8.7           25.7
# 26   ...                  $735               1.6           16.6
# 37   ...                  $790               3.7           41.5
# 50   ...               $12,671              12.1           23.5
# 98   ...                $9,986              17.7           28.0
# 118  ...                $1,244                25           15.3
# 125  ...                $5,929                 7           16.5
# 148  ...                $1,553               4.5           18.0
# 157  ...                $4,586              12.7           32.4
# 158  ...               $14,606               8.1           22.0
# 181  ...               $12,114               7.7         1087.5
#
#      FDI Inflow (Millions)  Public Debt (% of GDP)  GDP per Capita no Dollar  \
# 3                -2,254.50                    65.3                      6753
# 4                11,857.00                    52.6                     20876
# 26                     0.3                    56.7                       735
# 37                1,340.20                    15.7                       790
# 50                7,391.70                   103.3                     12671
# 98                       0                     4.7                      9986
# 118               2,293.10                   102.2                      1244
# 125               3,503.00                    23.4                      5929
# 148                    560                    58.4                      1553
# 157               1,065.30                   126.0                      4586
# 158                  -87.3                    72.1                     14606
# 181                    -68                    34.9                     12114
#
#              2018  Deaths - cumulative total per 100000 population      west  \
# 3     6452.355165                                           6.0000  Not West
# 4    20610.568550                                         283.0000      West
# 26     744.182072                                           0.0000  Not West
# 37   22002.645113                                         111.4625  Not West
# 50   22002.645113                                          24.0000  Not West
# 98   20764.164140                                          93.0000  Not West
# 118   1459.698413                                           7.0000  Not West
# 125   5990.850432                                           2.0000  Not West
# 148   1601.974029                                           2.0000  Not West
# 157   4767.689827                                          11.0000  Not West
# 158  15510.464640                                         226.0000      West
# 181  22002.645113                                         111.4625      West
#
#      Ability to service National Debt
# 3                            0.315467
# 4                            0.585551
# 26                           0.216931
# 37                           0.687898
# 50                           0.174250
# 98                           0.000000
# 118                          0.197652
# 125                          0.222222
# 148                          0.208904
# 157                          0.053175
# 158                          0.183079
# 181                          0.426934
#
# [12 rows x 38 columns]

# %%
result10.describe()
# Out:
#        World Rank  Region Rank  2019 Score  Property Rights  \
# count   12.000000    12.000000   12.000000        12.000000
# mean   143.166667    28.333333   44.133333        30.358333
# std     48.156626    13.411890   15.814110        13.388765
# min      0.000000     0.000000    0.000000         7.600000
# 25%    147.000000    23.000000   47.650000        24.125000
# 50%    159.500000    32.500000   48.750000        34.700000
# 75%    165.250000    39.250000   51.000000        36.625000
# max    179.000000    42.000000   57.300000        49.100000
#
#        Judical Effectiveness  Government Integrity  Tax Burden  \
# count              12.000000             12.000000   12.000000
# mean               30.583333             24.650000   72.158333
# std                 9.809720              7.577419   23.630506
# min                13.100000              7.900000    0.000000
# 25%                23.850000             20.500000   73.075000
# 50%                30.850000             26.200000   75.100000
# 75%                34.675000             28.375000   85.050000
# max                48.300000             35.500000   87.300000
#
#        Gov't Spending  Fiscal Health  Business Freedom  ...  \
# count       12.000000      12.000000         12.000000  ...
# mean        71.266667      36.058333         50.766667  ...
# std         26.946794      30.896409          8.366311  ...
# min          0.000000       0.000000         33.900000  ...
# 25%         64.700000      15.750000         47.450000  ...
# 50%         78.950000      21.650000         51.650000  ...
# 75%         86.775000      60.700000         55.875000  ...
# max         96.600000      96.900000         65.900000  ...
#
#        Corporate Tax Rate (%)  Tax Burden % of GDP  \
# count                12.00000            12.000000
# mean                 31.25000            13.741667
# std                   5.52885             8.112780
# min                  20.00000             0.000000
# 25%                  30.00000             9.775000
# 50%                  31.00000            12.750000
# 75%                  35.00000            18.550000
# max                  40.00000            30.800000
#
#        Gov't Expenditure % of GDP   GDP Growth Rate (%)  \
# count                    12.000000            12.000000
# mean                     34.858333             6.541667
# std                      34.310678            20.813783
# min                      10.600000           -14.000000
# 25%                      20.650000             0.525000
# 50%                      26.450000             2.950000
# 75%                      34.250000             3.425000
# max                     139.200000            70.800000
#
#        5 Year GDP Growth Rate (%)  Inflation (%)  Public Debt (% of GDP)  \
# count                   12.000000      12.000000               12.000000
# mean                     1.016667     113.225000               59.608333
# std                      4.567441     306.917369               37.225052
# min                     -7.900000      15.300000                4.700000
# 25%                      0.300000      17.650000               32.025000
# 50%                      2.800000      24.600000               57.550000
# 75%                      3.200000      31.875000               79.625000
# max                      6.100000    1087.500000              126.000000
#
#                2018  Deaths - cumulative total per 100000 population  \
# count     12.000000                                        12.000000
# mean   11992.490217                                        73.077083
# std     9187.623928                                        95.996523
# min      744.182072                                         0.000000
# 25%     3976.260877                                         5.000000
# 50%    10981.409902                                        17.500000
# 75%    21073.784383                                       111.462500
# max    22002.645113                                       283.000000
#
#        Ability to service National Debt
# count                         12.000000
# mean                           0.272672
# std                            0.202602
# min                            0.000000
# 25%                            0.180872
# 50%                            0.212918
# 75%                            0.343334
# max                            0.687898
#
# [8 rows x 27 columns]

# %%
result20=result6.sort_values('World Rank', ascending=True)

# %%
result20.head(20)
# Out:
#              Country Name             WEBNAME                        Region  \
# 78                   Iraq                Iraq  Middle East and North Africa
# 99          Liechtenstein       Liechtenstein                        Europe
# 153               Somalia             Somalia            Sub-Saharan Africa
# 98                  Libya               Libya  Middle East and North Africa
# 183                 Yemen               Yemen  Middle East and North Africa
# 161                 Syria               Syria  Middle East and North Africa
# 72              Hong Kong            HongKong                  Asia-Pacific
# 149             Singapore           Singapore                  Asia-Pacific
# 122           New Zealand          NewZealand                  Asia-Pacific
# 160           Switzerland         Switzerland                        Europe
# 6               Australia           Australia                  Asia-Pacific
# 79                Ireland             Ireland                        Europe
# 176        United Kingdom       UnitedKingdom                        Europe
# 29                 Canada              Canada                      Americas
# 175  United Arab Emirates  UnitedArabEmirates  Middle East and North Africa
# 162               Taiwan               Taiwan                  Asia-Pacific
# 74                Iceland             Iceland                        Europe
# 177         United States        UnitedStates                      Americas
# 121           Netherlands         Netherlands                        Europe
# 45                Denmark             Denmark                        Europe
#
#      World Rank  Region Rank  2019 Score  Property Rights  \
# 78          0.0          0.0         0.0             37.0
# 99          0.0          0.0         0.0              0.0
# 153         0.0          0.0         0.0             33.7
# 98          0.0          0.0         0.0              7.6
# 183         0.0          0.0         0.0             19.6
# 161         0.0          0.0         0.0             37.0
# 72          1.0          1.0        90.2             93.3
# 149         2.0          2.0        89.4             97.4
# 122         3.0          3.0        84.4             95.0
# 160         4.0          1.0        81.9             85.3
# 6           5.0          4.0        80.9             79.1
# 79          6.0          2.0        80.5             85.8
# 176         7.0          3.0        78.9             92.3
# 29          8.0          1.0        77.7             87.0
# 175         9.0          1.0        77.6             81.8
# 162        10.0          5.0        77.3             85.4
# 74         11.0          4.0        77.1             87.4
# 177        12.0          2.0        76.8             79.3
# 121        13.0          5.0        76.8             88.0
# 45         14.0          6.0        76.7             86.2
#
#      Judical Effectiveness  Government Integrity  Tax Burden  ...  \
# 78                    12.3                  20.3         0.0  ...
# 99                     0.0                   0.0         0.0  ...
# 153                   26.6                   7.9         0.0  ...
# 98                    24.4                  15.8         0.0  ...
# 183                   22.2                  20.3         0.0  ...
# 161                   24.4                  20.3         0.0  ...
# 72                    75.3                  83.8        93.1  ...
# 149                   92.4                  95.1        90.4  ...
# 122                   83.5                  96.7        71.0  ...
# 160                   82.0                  88.0        70.5  ...
# 6                     86.5                  79.9        62.8  ...
# 79                    68.4                  78.0        76.3  ...
# 176                   85.9                  83.8        64.7  ...
# 29                    69.4                  84.6        76.8  ...
# 175                   87.1                  78.8        99.2  ...
# 162                   70.1                  69.2        75.0  ...
# 74                    63.8                  83.8        72.7  ...
# 177                   78.6                  77.4        75.1  ...
# 121                   74.7                  89.1        51.6  ...
# 45                    77.8                  85.8        42.0  ...
#
#      GDP per Capita (PPP)  Unemployment (%)  Inflation (%)  \
# 78                $16,954               8.2            0.1
# 99   $139,100 (2009 est.)        2.1 (2016)            0.0
# 153                     0                 6            0.0
# 98                 $9,986              17.7           28.0
# 183                $1,287                14            4.9
# 161                     0              14.9            0.0
# 72                $61,393               3.1            1.5
# 149               $93,906                 2            0.6
# 122               $38,934               4.9            1.9
# 160               $61,422               4.8            0.5
# 6                 $50,334               5.6            2.0
# 79                $75,538               6.4            0.3
# 176               $44,118               4.3            2.7
# 29                $48,265               6.3            1.6
# 175               $67,741               1.7            2.0
# 162               $50,294               3.8            0.6
# 74                $51,842               2.8            1.8
# 177               $59,501               4.4            2.1
# 121               $53,635               4.8            1.3
# 45                $49,883               5.7            1.1
#
#      FDI Inflow (Millions)  Public Debt (% of GDP)  GDP per Capita no Dollar  \
# 78               -5,032.40                    58.0                     16954
# 99                       0                     0.0               1391002009.
# 153                    384                     0.0                         0
# 98                       0                     4.7                      9986
# 183                 -269.9                   141.0                      1287
# 161                      0                     0.0                         0
# 72              104,333.00                     0.1                     61393
# 149              62,006.00                   110.9                     93906
# 122               3,572.00                    26.4                     38934
# 160              40,986.10                    42.8                     61422
# 6                46,368.00                    41.6                     50334
# 79               28,974.60                    68.5                     75538
# 176              15,090.00                    87.0                     44118
# 29               24,243.80                    89.7                     48265
# 175              10,354.20                    19.5                     67741
# 162               3,255.00                    35.2                     50294
# 74                    -5.4                    40.9                     51842
# 177             275,381.00                   107.8                     59501
# 121              57,956.70                    56.7                     53635
# 45               -3,114.70                    36.4                     49883
#
#               2018  Deaths - cumulative total per 100000 population      west  \
# 78    17435.853930                                          63.0000  Not West
# 99    22002.645113                                         209.0000      West
# 153   22002.645113                                           9.0000  Not West
# 98    20764.164140                                          93.0000  Not West
# 183   22002.645113                                           7.0000  Not West
# 161   22002.645113                                         111.4625  Not West
# 72    22002.645113                                         111.4625  Not West
# 149  101531.630200                                          22.0000  Not West
# 122   41005.420870                                           8.0000  Not West
# 160   68060.941050                                         150.0000      West
# 6     51663.365090                                          25.0000  Not West
# 79    83203.394680                                         137.0000      West
# 176   45973.573500                                         111.4625      West
# 29    48130.255970                                         100.0000      West
# 175   75075.257410                                          23.0000  Not West
# 162   22002.645113                                         111.4625  Not West
# 74    57303.060780                                          28.0000      West
# 177   62794.585650                                         111.4625      West
# 121   56328.941140                                         127.0000      West
# 45    55671.165270                                          99.0000      West
#
#      Ability to service National Debt
# 78                           0.000000
# 99                                inf
# 153                               inf
# 98                           0.000000
# 183                          0.000000
# 161                               inf
# 72                         140.000000
# 149                          0.123535
# 122                          1.215909
# 160                          0.649533
# 6                            0.677885
# 79                           0.335766
# 176                          0.381609
# 29                           0.353400
# 175                          0.456410
# 162                          0.252841
# 74                           0.889976
# 177                          0.241187
# 121                          0.684303
# 45                           1.260989
#
# [20 rows x 38 columns]

# %%
result6.describe()
# Out:
#        World Rank  Region Rank  2019 Score  Property Rights  \
# count  186.000000   186.000000  186.000000       186.000000
# mean    87.580645    19.876344   58.808065        52.046237
# std     53.702951    13.047969   15.442965        19.928304
# min      0.000000     0.000000    0.000000         0.000000
# 25%     41.250000     9.000000   53.375000        37.000000
# 50%     87.500000    19.000000   60.200000        50.000000
# 75%    133.750000    30.000000   67.600000        65.700000
# max    180.000000    47.000000   90.200000        97.400000
#
#        Judical Effectiveness  Government Integrity  Tax Burden  \
# count             186.000000            186.000000  186.000000
# mean               44.658065             41.247312   74.722043
# std                18.353433             19.972454   18.865848
# min                 0.000000              0.000000    0.000000
# 25%                31.000000             26.600000   70.425000
# 50%                42.900000             35.500000   77.250000
# 75%                54.675000             50.300000   85.275000
# max                92.400000             96.700000   99.800000
#
#        Gov't Spending  Fiscal Health  Business Freedom  ...  \
# count      186.000000     186.000000        186.000000  ...
# mean        63.168280      64.932258         63.172581  ...
# std         24.352493      32.589752         16.430392  ...
# min          0.000000       0.000000          0.000000  ...
# 25%         50.575000      34.225000         54.025000  ...
# 50%         68.350000      80.000000         63.900000  ...
# 75%         81.750000      91.000000         74.975000  ...
# max         96.600000     100.000000         96.400000  ...
#
#        Corporate Tax Rate (%)  Tax Burden % of GDP  \
# count              186.000000           186.000000
# mean                23.505914            21.323656
# std                  9.289897            10.819156
# min                  0.000000             0.000000
# 25%                 19.000000            13.625000
# 50%                 25.000000            20.550000
# 75%                 30.000000            29.050000
# max                 50.000000            47.000000
#
#        Gov't Expenditure % of GDP   GDP Growth Rate (%)  \
# count                   186.000000           186.000000
# mean                     33.135484             3.432796
# std                      16.081173             5.815185
# min                       0.000000           -14.000000
# 25%                      23.525000             1.800000
# 50%                      32.050000             3.150000
# 75%                      39.950000             4.600000
# max                     139.200000            70.800000
#
#        5 Year GDP Growth Rate (%)  Inflation (%)  Public Debt (% of GDP)  \
# count                  186.000000     186.000000              186.000000
# mean                     2.936022      10.358602               55.254839
# std                      2.927049      79.647279               34.776381
# min                    -16.100000      -0.900000                0.000000
# 25%                      1.800000       1.225000               34.700000
# 50%                      3.000000       2.400000               49.100000
# 75%                      4.400000       5.300000               69.550000
# max                      9.900000    1087.500000              236.400000
#
#                 2018  Deaths - cumulative total per 100000 population  \
# count     186.000000                                       186.000000
# mean    22002.645113                                       111.462500
# std     21213.689345                                       115.915808
# min       744.182072                                         0.000000
# 25%      6680.561151                                        16.500000
# 50%     18140.374880                                        97.500000
# 75%     27804.759170                                       156.750000
# max    126898.425900                                       644.000000
#
#        Ability to service National Debt
# count                        186.000000
# mean                                inf
# std                                 NaN
# min                            0.000000
# 25%                            0.272088
# 50%                            0.408223
# 75%                            0.633052
# max                                 inf
#
# [8 rows x 27 columns]

# %%
result11=result6[result6['2018'] > 60000]

# %%
result11
# Out:
#              Country Name             WEBNAME                        Region  \
# 22      Brunei Darussalam             Brunei                   Asia-Pacific
# 79                Ireland             Ireland                        Europe
# 91                 Kuwait              Kuwait  Middle East and North Africa
# 101            Luxembourg          Luxembourg                        Europe
# 126                Norway              Norway                        Europe
# 136                 Qatar               Qatar  Middle East and North Africa
# 149             Singapore           Singapore                  Asia-Pacific
# 160           Switzerland         Switzerland                        Europe
# 175  United Arab Emirates  UnitedArabEmirates  Middle East and North Africa
# 177         United States        UnitedStates                      Americas
#
#      World Rank  Region Rank  2019 Score  Property Rights  \
# 22         63.0         14.0        65.1             64.0
# 79          6.0          2.0        80.5             85.8
# 91         90.0          8.0        60.8             52.9
# 101        17.0          9.0        75.9             83.0
# 126        26.0         15.0        73.0             86.1
# 136        28.0          3.0        72.6             64.5
# 149         2.0          2.0        89.4             97.4
# 160         4.0          1.0        81.9             85.3
# 175         9.0          1.0        77.6             81.8
# 177        12.0          2.0        76.8             79.3
#
#      Judical Effectiveness  Government Integrity  Tax Burden  ...  \
# 22                    56.0                  43.7        90.7  ...
# 79                    68.4                  78.0        76.3  ...
# 91                    43.3                  35.3        97.7  ...
# 101                   72.4                  85.8        65.4  ...
# 126                   81.2                  92.3        57.4  ...
# 136                   60.0                  77.4        99.7  ...
# 149                   92.4                  95.1        90.4  ...
# 160                   82.0                  88.0        70.5  ...
# 175                   87.1                  78.8        99.2  ...
# 177                   78.6                  77.4        75.1  ...
#
#      GDP per Capita (PPP)  Unemployment (%)  Inflation (%)  \
# 22                $78,196               7.1           -0.1
# 79                $75,538               6.4            0.3
# 91                $66,163               2.1            1.5
# 101              $106,374               5.5            2.1
# 126               $71,831               4.2            1.9
# 136              $124,529               0.1            0.4
# 149               $93,906                 2            0.6
# 160               $61,422               4.8            0.5
# 175               $67,741               1.7            2.0
# 177               $59,501               4.4            2.1
#
#      FDI Inflow (Millions)  Public Debt (% of GDP)  GDP per Capita no Dollar  \
# 22                   -46.3                     2.7                     78196
# 79               28,974.60                    68.5                     75538
# 91                   300.5                    20.6                     66163
# 101               6,622.70                    23.0                    106374
# 126              -8,296.90                    36.7                     71831
# 136                    986                    54.0                    124529
# 149              62,006.00                   110.9                     93906
# 160              40,986.10                    42.8                     61422
# 175              10,354.20                    19.5                     67741
# 177             275,381.00                   107.8                     59501
#
#              2018  Deaths - cumulative total per 100000 population      west  \
# 22    80920.04868                                          35.0000  Not West
# 79    83203.39468                                         137.0000      West
# 91    72897.56235                                          60.0000  Not West
# 101  113337.42050                                         166.0000      West
# 126   65510.58527                                          47.0000      West
# 136  126898.42590                                          23.0000  Not West
# 149  101531.63020                                          22.0000  Not West
# 160   68060.94105                                         150.0000      West
# 175   75075.25741                                          23.0000  Not West
# 177   62794.58565                                         111.4625      West
#
#      Ability to service National Debt
# 22                           8.962963
# 79                           0.335766
# 91                           0.077670
# 101                          1.613043
# 126                          1.035422
# 136                          0.105556
# 149                          0.123535
# 160                          0.649533
# 175                          0.456410
# 177                          0.241187
#
# [10 rows x 38 columns]

# %%
result11.describe()
# Out:
#        World Rank  Region Rank  2019 Score  Property Rights  \
# count   10.000000    10.000000   10.000000        10.000000
# mean    25.700000     5.700000   75.360000        78.010000
# std     28.856157     5.417051    8.193114        13.356185
# min      2.000000     1.000000   60.800000        52.900000
# 25%      6.750000     2.000000   72.700000        68.200000
# 50%     14.500000     2.500000   76.350000        82.400000
# 75%     27.500000     8.750000   79.775000        85.675000
# max     90.000000    15.000000   89.400000        97.400000
#
#        Judical Effectiveness  Government Integrity  Tax Burden  \
# count              10.000000             10.000000   10.000000
# mean               72.140000             75.180000   82.240000
# std                15.307892             19.942573   15.254741
# min                43.300000             35.300000   57.400000
# 25%                62.100000             77.400000   71.650000
# 50%                75.500000             78.400000   83.350000
# 75%                81.800000             87.450000   95.950000
# max                92.400000             95.100000   99.700000
#
#        Gov't Spending  Fiscal Health  Business Freedom  ...  \
# count       10.000000      10.000000         10.000000  ...
# mean        56.470000      81.660000         78.000000  ...
# std         22.227913      25.688874         10.131908  ...
# min         17.300000      20.000000         57.400000  ...
# 25%         49.150000      82.225000         72.250000  ...
# 50%         58.500000      91.500000         80.050000  ...
# 75%         67.800000      97.050000         83.625000  ...
# max         90.700000      99.100000         90.800000  ...
#
#        Corporate Tax Rate (%)  Tax Burden % of GDP  \
# count               10.000000            10.000000
# mean                14.900000            20.600000
# std                  8.579044            12.658945
# min                  0.000000             1.600000
# 25%                 13.125000            10.100000
# 50%                 17.500000            23.600000
# 75%                 20.375000            27.350000
# max                 24.000000            38.000000
#
#        Gov't Expenditure % of GDP   GDP Growth Rate (%)  \
# count                    10.000000             10.00000
# mean                     36.850000              2.07000
# std                      10.181601              2.66877
# min                      17.600000             -2.50000
# 25%                      32.800000              0.65000
# 50%                      37.200000              1.95000
# 75%                      41.125000              3.20000
# max                      52.500000              7.80000
#
#        5 Year GDP Growth Rate (%)  Inflation (%)  Public Debt (% of GDP)  \
# count                   10.000000      10.000000               10.000000
# mean                     2.750000       1.130000               48.650000
# std                      2.960199       0.868012               37.087442
# min                     -1.400000      -0.100000                2.700000
# 25%                      1.600000       0.425000               21.200000
# 50%                      2.750000       1.050000               39.750000
# 75%                      3.450000       1.975000               64.875000
# max                      9.700000       2.100000              110.900000
#
#                 2018  Deaths - cumulative total per 100000 population  \
# count      10.000000                                        10.000000
# mean    85022.985169                                        77.446250
# std     21747.208619                                        57.586334
# min     62794.585650                                        22.000000
# 25%     69270.096375                                        26.000000
# 50%     77997.653045                                        53.500000
# 75%     96949.571320                                       130.615625
# max    126898.425900                                       166.000000
#
#        Ability to service National Debt
# count                         10.000000
# mean                           1.360109
# std                            2.715047
# min                            0.077670
# 25%                            0.152948
# 50%                            0.396088
# 75%                            0.938950
# max                            8.962963
#
# [8 rows x 27 columns]

# %%
sns.heatmap(result9.corr(), annot=True, cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
# Govt spending has negative realtionship with both gdp and deaths per 100,000
#Govt spending has positive relationship with inflation
# Inflation has a slightly negative relationship with death
#Negative relationship with death is good

# %%
sns.jointplot(data=result6, x='2019 Score',  y='Deaths - cumulative total per 100000 population', kind='reg')

# %%
# Sligthy Positive relationship- not a good relationship. Need negative with deaths. Bad news

# %%
sns.jointplot(data=result6, x='2019 Score',  y='2018', kind='reg')

# %%
# Significant positive relationship

# %%
sns.jointplot(data=result6, x='Fiscal Health',  y='Deaths - cumulative total per 100000 population', kind='reg')

# %%
result12=result8.loc[:,['Gov\'t Spending', 'Inflation (%)', '2018', 'Region']]

# %%
result12
# Out:
#      Gov't Spending  Inflation (%)          2018                        Region
# 0              80.3            5.0   1955.006208                  Asia-Pacific
# 1              73.9            2.0  13364.155400                        Europe
# 2              48.7            5.6  15481.787620  Middle East and North Africa
# 3              80.7           31.7   6452.355165            Sub-Saharan Africa
# 4              49.5           25.7  20610.568550                      Americas
# ..              ...            ...           ...                           ...
# 180            54.1            3.1   3221.149823                  Asia-Pacific
# 182            74.1            3.5   7447.814334                  Asia-Pacific
# 183            83.7            4.9  22002.645113  Middle East and North Africa
# 184            80.1            6.6   4223.906936            Sub-Saharan Africa
# 185            74.5            1.3   3029.793005            Sub-Saharan Africa
#
# [185 rows x 4 columns]

# %%
sns.heatmap(result14.corr(), annot=True, cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
result14=result6.loc[:,['Deaths - cumulative total per 100000 population', 'Government Integrity', '2018', 'Tax Burden % of GDP']]

# %%
result6.corr()
# Out:
#                                                  World Rank  Region Rank  \
# World Rank                                         1.000000     0.758796
# Region Rank                                        0.758796     1.000000
# 2019 Score                                        -0.433914    -0.296845
# Property Rights                                   -0.703431    -0.443540
# Judical Effectiveness                             -0.639762    -0.486071
# Government Integrity                              -0.642157    -0.467609
# Tax Burden                                         0.217557     0.141147
# Gov't Spending                                     0.144412    -0.092548
# Fiscal Health                                     -0.396707    -0.185807
# Business Freedom                                  -0.597563    -0.405511
# Labor Freedom                                     -0.355037    -0.309210
# Monetary Freedom                                  -0.252978    -0.152600
# Trade Freedom                                     -0.312868    -0.149119
# Investment Freedom                                -0.587717    -0.414714
# Financial Freedom                                 -0.595522    -0.440075
# Tariff Rate (%)                                    0.532901     0.328258
# Income Tax Rate (%)                                0.030909     0.024463
# Corporate Tax Rate (%)                             0.337378     0.159598
# Tax Burden % of GDP                               -0.220923     0.084027
# Gov't Expenditure % of GDP                         0.007156     0.175102
# GDP Growth Rate (%)                               -0.107239    -0.080262
# 5 Year GDP Growth Rate (%)                         0.101739     0.016309
# Inflation (%)                                      0.152085     0.085357
# Public Debt (% of GDP)                             0.040961     0.086016
# 2018                                              -0.559469    -0.381783
# Deaths - cumulative total per 100000 population   -0.296033    -0.021623
# Ability to service National Debt                  -0.134129    -0.113970
#
#                                                  2019 Score  Property Rights  \
# World Rank                                        -0.433914        -0.703431
# Region Rank                                       -0.296845        -0.443540
# 2019 Score                                         1.000000         0.756877
# Property Rights                                    0.756877         1.000000
# Judical Effectiveness                              0.736967         0.828503
# Government Integrity                               0.702422         0.858950
# Tax Burden                                         0.573253         0.096316
# Gov't Spending                                     0.241808        -0.155676
# Fiscal Health                                      0.612750         0.377722
# Business Freedom                                   0.749542         0.785711
# Labor Freedom                                      0.572791         0.459556
# Monetary Freedom                                   0.682868         0.486534
# Trade Freedom                                      0.813485         0.627957
# Investment Freedom                                 0.686306         0.631102
# Financial Freedom                                  0.729630         0.694651
# Tariff Rate (%)                                   -0.390788        -0.430458
# Income Tax Rate (%)                                0.219728         0.206404
# Corporate Tax Rate (%)                            -0.005317        -0.204010
# Tax Burden % of GDP                                0.474171         0.534640
# Gov't Expenditure % of GDP                        -0.049734         0.158573
# GDP Growth Rate (%)                               -0.073615        -0.062410
# 5 Year GDP Growth Rate (%)                         0.307737         0.093847
# Inflation (%)                                     -0.174145        -0.189405
# Public Debt (% of GDP)                             0.086207         0.138398
# 2018                                               0.393567         0.624133
# Deaths - cumulative total per 100000 population    0.212006         0.285353
# Ability to service National Debt                   0.185292         0.167408
#
#                                                  Judical Effectiveness  \
# World Rank                                                   -0.639762
# Region Rank                                                  -0.486071
# 2019 Score                                                    0.736967
# Property Rights                                               0.828503
# Judical Effectiveness                                         1.000000
# Government Integrity                                          0.881659
# Tax Burden                                                    0.115263
# Gov't Spending                                               -0.060131
# Fiscal Health                                                 0.366417
# Business Freedom                                              0.736125
# Labor Freedom                                                 0.484208
# Monetary Freedom                                              0.455131
# Trade Freedom                                                 0.564890
# Investment Freedom                                            0.539192
# Financial Freedom                                             0.594406
# Tariff Rate (%)                                              -0.386612
# Income Tax Rate (%)                                           0.237736
# Corporate Tax Rate (%)                                       -0.119031
# Tax Burden % of GDP                                           0.431412
# Gov't Expenditure % of GDP                                    0.095574
# GDP Growth Rate (%)                                          -0.010852
# 5 Year GDP Growth Rate (%)                                    0.058387
# Inflation (%)                                                -0.144642
# Public Debt (% of GDP)                                        0.128124
# 2018                                                          0.586674
# Deaths - cumulative total per 100000 population               0.106556
# Ability to service National Debt                              0.137723
#
#                                                  Government Integrity  \
# World Rank                                                  -0.642157
# Region Rank                                                 -0.467609
# 2019 Score                                                   0.702422
# Property Rights                                              0.858950
# Judical Effectiveness                                        0.881659
# Government Integrity                                         1.000000
# Tax Burden                                                   0.034969
# Gov't Spending                                              -0.210625
# Fiscal Health                                                0.350495
# Business Freedom                                             0.724796
# Labor Freedom                                                0.447922
# Monetary Freedom                                             0.445713
# Trade Freedom                                                0.544825
# Investment Freedom                                           0.572165
# Financial Freedom                                            0.614925
# Tariff Rate (%)                                             -0.351810
# Income Tax Rate (%)                                          0.267521
# Corporate Tax Rate (%)                                      -0.168110
# Tax Burden % of GDP                                          0.473786
# Gov't Expenditure % of GDP                                   0.221668
# GDP Growth Rate (%)                                         -0.053099
# 5 Year GDP Growth Rate (%)                                   0.035100
# Inflation (%)                                               -0.144260
# Public Debt (% of GDP)                                       0.147444
# 2018                                                         0.701621
# Deaths - cumulative total per 100000 population              0.108052
# Ability to service National Debt                             0.168267
#
#                                                  Tax Burden  Gov't Spending  \
# World Rank                                         0.217557        0.144412
# Region Rank                                        0.141147       -0.092548
# 2019 Score                                         0.573253        0.241808
# Property Rights                                    0.096316       -0.155676
# Judical Effectiveness                              0.115263       -0.060131
# Government Integrity                               0.034969       -0.210625
# Tax Burden                                         1.000000        0.469927
# Gov't Spending                                     0.469927        1.000000
# Fiscal Health                                      0.252419        0.160750
# Business Freedom                                   0.272785       -0.035678
# Labor Freedom                                      0.362114        0.156271
# Monetary Freedom                                   0.397734        0.175011
# Trade Freedom                                      0.522415        0.137625
# Investment Freedom                                 0.114512       -0.019769
# Financial Freedom                                  0.185368       -0.038863
# Tariff Rate (%)                                   -0.121650        0.091724
# Income Tax Rate (%)                               -0.301615        0.009946
# Corporate Tax Rate (%)                            -0.109199        0.258900
# Tax Burden % of GDP                               -0.028420       -0.402901
# Gov't Expenditure % of GDP                        -0.200177       -0.716175
# GDP Growth Rate (%)                               -0.092799       -0.026318
# 5 Year GDP Growth Rate (%)                         0.392437        0.314779
# Inflation (%)                                      0.004617        0.000219
# Public Debt (% of GDP)                            -0.022104        0.022193
# 2018                                              -0.063685       -0.339112
# Deaths - cumulative total per 100000 population   -0.016300       -0.215399
# Ability to service National Debt                   0.084867        0.073081
#
#                                                  Fiscal Health  \
# World Rank                                           -0.396707
# Region Rank                                          -0.185807
# 2019 Score                                            0.612750
# Property Rights                                       0.377722
# Judical Effectiveness                                 0.366417
# Government Integrity                                  0.350495
# Tax Burden                                            0.252419
# Gov't Spending                                        0.160750
# Fiscal Health                                         1.000000
# Business Freedom                                      0.386313
# Labor Freedom                                         0.243721
# Monetary Freedom                                      0.391583
# Trade Freedom                                         0.410038
# Investment Freedom                                    0.316087
# Financial Freedom                                     0.322315
# Tariff Rate (%)                                      -0.230737
# Income Tax Rate (%)                                   0.156873
# Corporate Tax Rate (%)                                0.035060
# Tax Burden % of GDP                                   0.275256
# Gov't Expenditure % of GDP                           -0.037972
# GDP Growth Rate (%)                                   0.060590
# 5 Year GDP Growth Rate (%)                            0.205492
# Inflation (%)                                        -0.116395
# Public Debt (% of GDP)                               -0.221337
# 2018                                                  0.174488
# Deaths - cumulative total per 100000 population       0.156920
# Ability to service National Debt                      0.086935
#
#                                                  Business Freedom  ...  \
# World Rank                                              -0.597563  ...
# Region Rank                                             -0.405511  ...
# 2019 Score                                               0.749542  ...
# Property Rights                                          0.785711  ...
# Judical Effectiveness                                    0.736125  ...
# Government Integrity                                     0.724796  ...
# Tax Burden                                               0.272785  ...
# Gov't Spending                                          -0.035678  ...
# Fiscal Health                                            0.386313  ...
# Business Freedom                                         1.000000  ...
# Labor Freedom                                            0.567549  ...
# Monetary Freedom                                         0.548747  ...
# Trade Freedom                                            0.650908  ...
# Investment Freedom                                       0.530771  ...
# Financial Freedom                                        0.574301  ...
# Tariff Rate (%)                                         -0.466540  ...
# Income Tax Rate (%)                                      0.105549  ...
# Corporate Tax Rate (%)                                  -0.177052  ...
# Tax Burden % of GDP                                      0.467457  ...
# Gov't Expenditure % of GDP                               0.089303  ...
# GDP Growth Rate (%)                                     -0.036678  ...
# 5 Year GDP Growth Rate (%)                               0.077037  ...
# Inflation (%)                                           -0.147303  ...
# Public Debt (% of GDP)                                   0.137359  ...
# 2018                                                     0.460243  ...
# Deaths - cumulative total per 100000 population          0.229103  ...
# Ability to service National Debt                         0.172389  ...
#
#                                                  Corporate Tax Rate (%)  \
# World Rank                                                     0.337378
# Region Rank                                                    0.159598
# 2019 Score                                                    -0.005317
# Property Rights                                               -0.204010
# Judical Effectiveness                                         -0.119031
# Government Integrity                                          -0.168110
# Tax Burden                                                    -0.109199
# Gov't Spending                                                 0.258900
# Fiscal Health                                                  0.035060
# Business Freedom                                              -0.177052
# Labor Freedom                                                 -0.012991
# Monetary Freedom                                               0.066395
# Trade Freedom                                                 -0.020164
# Investment Freedom                                            -0.055368
# Financial Freedom                                             -0.118597
# Tariff Rate (%)                                                0.157382
# Income Tax Rate (%)                                            0.596172
# Corporate Tax Rate (%)                                         1.000000
# Tax Burden % of GDP                                            0.053613
# Gov't Expenditure % of GDP                                    -0.139214
# GDP Growth Rate (%)                                            0.006747
# 5 Year GDP Growth Rate (%)                                     0.093396
# Inflation (%)                                                  0.100244
# Public Debt (% of GDP)                                         0.085322
# 2018                                                          -0.344327
# Deaths - cumulative total per 100000 population               -0.158735
# Ability to service National Debt                              -0.066249
#
#                                                  Tax Burden % of GDP  \
# World Rank                                                 -0.220923
# Region Rank                                                 0.084027
# 2019 Score                                                  0.474171
# Property Rights                                             0.534640
# Judical Effectiveness                                       0.431412
# Government Integrity                                        0.473786
# Tax Burden                                                 -0.028420
# Gov't Spending                                             -0.402901
# Fiscal Health                                               0.275256
# Business Freedom                                            0.467457
# Labor Freedom                                               0.153680
# Monetary Freedom                                            0.411932
# Trade Freedom                                               0.498677
# Investment Freedom                                          0.507743
# Financial Freedom                                           0.458063
# Tariff Rate (%)                                            -0.300459
# Income Tax Rate (%)                                         0.416053
# Corporate Tax Rate (%)                                      0.053613
# Tax Burden % of GDP                                         1.000000
# Gov't Expenditure % of GDP                                  0.371802
# GDP Growth Rate (%)                                        -0.102652
# 5 Year GDP Growth Rate (%)                                 -0.056523
# Inflation (%)                                              -0.059580
# Public Debt (% of GDP)                                      0.248672
# 2018                                                        0.281366
# Deaths - cumulative total per 100000 population             0.421903
# Ability to service National Debt                           -0.035668
#
#                                                  Gov't Expenditure % of GDP   \
# World Rank                                                          0.007156
# Region Rank                                                         0.175102
# 2019 Score                                                         -0.049734
# Property Rights                                                     0.158573
# Judical Effectiveness                                               0.095574
# Government Integrity                                                0.221668
# Tax Burden                                                         -0.200177
# Gov't Spending                                                     -0.716175
# Fiscal Health                                                      -0.037972
# Business Freedom                                                    0.089303
# Labor Freedom                                                      -0.001134
# Monetary Freedom                                                    0.061482
# Trade Freedom                                                      -0.057257
# Investment Freedom                                                 -0.009104
# Financial Freedom                                                   0.017219
# Tariff Rate (%)                                                     0.033003
# Income Tax Rate (%)                                                 0.036286
# Corporate Tax Rate (%)                                             -0.139214
# Tax Burden % of GDP                                                 0.371802
# Gov't Expenditure % of GDP                                          1.000000
# GDP Growth Rate (%)                                                 0.358315
# 5 Year GDP Growth Rate (%)                                         -0.233762
# Inflation (%)                                                       0.016717
# Public Debt (% of GDP)                                              0.010192
# 2018                                                                0.233386
# Deaths - cumulative total per 100000 population                     0.159450
# Ability to service National Debt                                   -0.068334
#
#                                                  GDP Growth Rate (%)  \
# World Rank                                                 -0.107239
# Region Rank                                                -0.080262
# 2019 Score                                                 -0.073615
# Property Rights                                            -0.062410
# Judical Effectiveness                                      -0.010852
# Government Integrity                                       -0.053099
# Tax Burden                                                 -0.092799
# Gov't Spending                                             -0.026318
# Fiscal Health                                               0.060590
# Business Freedom                                           -0.036678
# Labor Freedom                                               0.016629
# Monetary Freedom                                            0.015967
# Trade Freedom                                              -0.200726
# Investment Freedom                                         -0.086077
# Financial Freedom                                          -0.066844
# Tariff Rate (%)                                            -0.099454
# Income Tax Rate (%)                                        -0.056184
# Corporate Tax Rate (%)                                      0.006747
# Tax Burden % of GDP                                        -0.102652
# Gov't Expenditure % of GDP                                  0.358315
# GDP Growth Rate (%)                                         1.000000
# 5 Year GDP Growth Rate (%)                                  0.163391
# Inflation (%)                                              -0.200839
# Public Debt (% of GDP)                                     -0.157394
# 2018                                                       -0.078253
# Deaths - cumulative total per 100000 population            -0.032680
# Ability to service National Debt                            0.000052
#
#                                                  5 Year GDP Growth Rate (%)  \
# World Rank                                                         0.101739
# Region Rank                                                        0.016309
# 2019 Score                                                         0.307737
# Property Rights                                                    0.093847
# Judical Effectiveness                                              0.058387
# Government Integrity                                               0.035100
# Tax Burden                                                         0.392437
# Gov't Spending                                                     0.314779
# Fiscal Health                                                      0.205492
# Business Freedom                                                   0.077037
# Labor Freedom                                                      0.106441
# Monetary Freedom                                                   0.205688
# Trade Freedom                                                      0.162019
# Investment Freedom                                                 0.024499
# Financial Freedom                                                  0.094268
# Tariff Rate (%)                                                   -0.030568
# Income Tax Rate (%)                                                0.066373
# Corporate Tax Rate (%)                                             0.093396
# Tax Burden % of GDP                                               -0.056523
# Gov't Expenditure % of GDP                                        -0.233762
# GDP Growth Rate (%)                                                0.163391
# 5 Year GDP Growth Rate (%)                                         1.000000
# Inflation (%)                                                     -0.271148
# Public Debt (% of GDP)                                            -0.155135
# 2018                                                              -0.136062
# Deaths - cumulative total per 100000 population                   -0.139703
# Ability to service National Debt                                  -0.010500
#
#                                                  Inflation (%)  \
# World Rank                                            0.152085
# Region Rank                                           0.085357
# 2019 Score                                           -0.174145
# Property Rights                                      -0.189405
# Judical Effectiveness                                -0.144642
# Government Integrity                                 -0.144260
# Tax Burden                                            0.004617
# Gov't Spending                                        0.000219
# Fiscal Health                                        -0.116395
# Business Freedom                                     -0.147303
# Labor Freedom                                        -0.151025
# Monetary Freedom                                     -0.430380
# Trade Freedom                                        -0.072999
# Investment Freedom                                   -0.203984
# Financial Freedom                                    -0.154876
# Tariff Rate (%)                                       0.066330
# Income Tax Rate (%)                                   0.027476
# Corporate Tax Rate (%)                                0.100244
# Tax Burden % of GDP                                  -0.059580
# Gov't Expenditure % of GDP                            0.016717
# GDP Growth Rate (%)                                  -0.200839
# 5 Year GDP Growth Rate (%)                           -0.271148
# Inflation (%)                                         1.000000
# Public Debt (% of GDP)                               -0.041733
# 2018                                                 -0.019155
# Deaths - cumulative total per 100000 population      -0.010159
# Ability to service National Debt                     -0.009949
#
#                                                  Public Debt (% of GDP)  \
# World Rank                                                     0.040961
# Region Rank                                                    0.086016
# 2019 Score                                                     0.086207
# Property Rights                                                0.138398
# Judical Effectiveness                                          0.128124
# Government Integrity                                           0.147444
# Tax Burden                                                    -0.022104
# Gov't Spending                                                 0.022193
# Fiscal Health                                                 -0.221337
# Business Freedom                                               0.137359
# Labor Freedom                                                  0.074569
# Monetary Freedom                                               0.200059
# Trade Freedom                                                  0.151704
# Investment Freedom                                             0.158762
# Financial Freedom                                              0.099808
# Tariff Rate (%)                                               -0.028802
# Income Tax Rate (%)                                            0.242026
# Corporate Tax Rate (%)                                         0.085322
# Tax Burden % of GDP                                            0.248672
# Gov't Expenditure % of GDP                                     0.010192
# GDP Growth Rate (%)                                           -0.157394
# 5 Year GDP Growth Rate (%)                                    -0.155135
# Inflation (%)                                                 -0.041733
# Public Debt (% of GDP)                                         1.000000
# 2018                                                           0.068253
# Deaths - cumulative total per 100000 population                0.043856
# Ability to service National Debt                              -0.151586
#
#                                                      2018  \
# World Rank                                      -0.559469
# Region Rank                                     -0.381783
# 2019 Score                                       0.393567
# Property Rights                                  0.624133
# Judical Effectiveness                            0.586674
# Government Integrity                             0.701621
# Tax Burden                                      -0.063685
# Gov't Spending                                  -0.339112
# Fiscal Health                                    0.174488
# Business Freedom                                 0.460243
# Labor Freedom                                    0.243084
# Monetary Freedom                                 0.175304
# Trade Freedom                                    0.351444
# Investment Freedom                               0.408464
# Financial Freedom                                0.486991
# Tariff Rate (%)                                 -0.342725
# Income Tax Rate (%)                              0.005613
# Corporate Tax Rate (%)                          -0.344327
# Tax Burden % of GDP                              0.281366
# Gov't Expenditure % of GDP                       0.233386
# GDP Growth Rate (%)                             -0.078253
# 5 Year GDP Growth Rate (%)                      -0.136062
# Inflation (%)                                   -0.019155
# Public Debt (% of GDP)                           0.068253
# 2018                                             1.000000
# Deaths - cumulative total per 100000 population  0.165265
# Ability to service National Debt                 0.017394
#
#                                                  Deaths - cumulative total per 100000 population  \
# World Rank                                                                             -0.296033
# Region Rank                                                                            -0.021623
# 2019 Score                                                                              0.212006
# Property Rights                                                                         0.285353
# Judical Effectiveness                                                                   0.106556
# Government Integrity                                                                    0.108052
# Tax Burden                                                                             -0.016300
# Gov't Spending                                                                         -0.215399
# Fiscal Health                                                                           0.156920
# Business Freedom                                                                        0.229103
# Labor Freedom                                                                           0.069178
# Monetary Freedom                                                                        0.139199
# Trade Freedom                                                                           0.288215
# Investment Freedom                                                                      0.371442
# Financial Freedom                                                                       0.345316
# Tariff Rate (%)                                                                        -0.276961
# Income Tax Rate (%)                                                                    -0.019422
# Corporate Tax Rate (%)                                                                 -0.158735
# Tax Burden % of GDP                                                                     0.421903
# Gov't Expenditure % of GDP                                                              0.159450
# GDP Growth Rate (%)                                                                    -0.032680
# 5 Year GDP Growth Rate (%)                                                             -0.139703
# Inflation (%)                                                                          -0.010159
# Public Debt (% of GDP)                                                                  0.043856
# 2018                                                                                    0.165265
# Deaths - cumulative total per 100000 population                                         1.000000
# Ability to service National Debt                                                        0.003826
#
#                                                  Ability to service National Debt
# World Rank                                                              -0.134129
# Region Rank                                                             -0.113970
# 2019 Score                                                               0.185292
# Property Rights                                                          0.167408
# Judical Effectiveness                                                    0.137723
# Government Integrity                                                     0.168267
# Tax Burden                                                               0.084867
# Gov't Spending                                                           0.073081
# Fiscal Health                                                            0.086935
# Business Freedom                                                         0.172389
# Labor Freedom                                                            0.170662
# Monetary Freedom                                                         0.091177
# Trade Freedom                                                            0.131202
# Investment Freedom                                                       0.118317
# Financial Freedom                                                        0.166111
# Tariff Rate (%)                                                         -0.107204
# Income Tax Rate (%)                                                     -0.080997
# Corporate Tax Rate (%)                                                  -0.066249
# Tax Burden % of GDP                                                     -0.035668
# Gov't Expenditure % of GDP                                              -0.068334
# GDP Growth Rate (%)                                                      0.000052
# 5 Year GDP Growth Rate (%)                                              -0.010500
# Inflation (%)                                                           -0.009949
# Public Debt (% of GDP)                                                  -0.151586
# 2018                                                                     0.017394
# Deaths - cumulative total per 100000 population                          0.003826
# Ability to service National Debt                                         1.000000
#
# [27 rows x 27 columns]

# %%
# Analysis
import pandas as pd
import numpy as np

# Plotting
import matplotlib.pyplot as plt
import seaborn as sns

# Models
from sklearn.linear_model import LinearRegression
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB

# Reporting
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn import tree
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold

# %%
X = result6[['2019 Score']] # Pass in a list, expecting a 2D array
y = result6['2018']

# %%
reg = LinearRegression().fit(X, y)

# %%
reg.predict([[50]])
# Out:
# array([17240.70107116])

# %%
reg.predict([[75]])
# Out:
# array([30756.56495193])

# %%
reg.score(X, y)
# Out:
# 0.15489470937607153

# %%
result6['Region'].value_counts()
# Out:
# Sub-Saharan Africa              48
# Europe                          45
# Asia-Pacific                    43
# Americas                        32
# Middle East and North Africa    18
# Name: Region, dtype: int64

# %%
def Estimate(Freedom):
    return reg.predict([[Freedom]])

# %%
Estimate(26)
# Out:
# array([4265.47174562])
